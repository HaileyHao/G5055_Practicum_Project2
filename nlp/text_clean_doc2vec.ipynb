# %%
import pandas as pd 
import numpy as np
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
import re
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/hannahz/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.set_option('display.max_colwidth', None)

# %%
#download filled definition from google doc as fill.xlsx(csv shows weird character), read in to pandas
new_def = pd.read_excel('fill-3.xlsx')
# combined with the original gaol-target-indicator-definition
df = pd.read_csv('goal_target_indicator_definition.csv')
# use the new filled definition column
df['definition'] = new_def['definition']
#drop the pdf_name column
df = df.drop(['pdf_name'], axis = 1)

# %%
# save it as xlsx (csv shows weird character)
#df.to_excel('definition_filled.xlsx', index = False)

# %%
df = pd.read_excel('definition_filled.xlsx')

# %% [markdown]
# ### clean the definition column

# %%
#remove \n
df['definition'] = df['definition'].replace(r'\n','', regex=True) 
#remove multiple whitespace
df['definition'] = df['definition'].replace('\s+', ' ', regex=True)
#remove white space in the beginning and end
df['definition'] = df['definition'].str.strip()
stop_words_l=stopwords.words('english')
# removing special characters and stop words from the text and lower case
df['definition']=df['definition'].apply(lambda x: " ".join(re.sub(r'[^a-zA-Z0-9$]','',w).lower() for w in x.split() if re.sub(r'[^a-zA-Z0-9$]',' ',w).lower() not in stop_words_l) )

#remove white space 
df['definition'] = df['definition'].replace('\s+', ' ', regex=True)

# %%
# save the cleaned definitions as xlsx 
#df.to_excel('definition_cleaned.xlsx', index = False)

# %%
# select the goal index out of index eg 1, 2
goal_num = df['Index']
df['goal_num'] = [re.findall(r'^(\d+).', goal)[0] for goal in goal_num]

# %%
df['definition']
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 4                                                                                                                                                                                                                                                                                                                                                            following key concepts defined support indicator context poverty eradicationbasic services refer public service provision systems meet human basic needs including drinkingwater sanitation hygiene energy mobility waste collection health care education informationtechnologies basis cervices indicator therefore based 9 components componentsare captured various standalone indicators sdgs means concepts definitionsof sdg indicator 141 derived specific sdg indicatorsaccess basic services implies sufficient affordable service reliably available adequatequality1 access basic drinking water services refers use drinking water improvedsource available collection time 30 minutes round tripincluding queuing improved sources include piped water boreholes tube wells protecteddug wells protected springs packaged delivered water definition based thejmp drinking water ladder foundation sdg indicator 611 proportion ofpopulation using safely managed drinking water services2 access basic sanitation services refers use improved facilities sharedwith households improved facilities include flushpour flush piped sewer systemsseptic tanks pit latrines ventilated improved pit latrines composting toilets pit latrines withslabs definition based jmp sanitation ladder foundation sdgindicator 621 proportion population using safely managed sanitation services b ahandwashing facility soap water3 access basic hygiene facilities refers availability handwashing facility premises withsoap water handwashing facilities may fixed mobile include sink tap waterbuckets taps tippytaps jugs basins designated handwashing soap includes barsoap liquid soap powder detergent soapy water include ash soil sand orother handwashing agents definition based jmp hygiene ladder thefoundation sdg indicator 621 proportion population using safely managed sanitationservices b handwashing facility soap waterfor many low middleincome countries achieving universal access basic drinking water sanitationand hygiene remains high priority help achieve access safely managed services thetarget sdgs 61 62 4 access clean fuels technology refers use fuels technology defined bythe emission rate targets specific fuel recommendations ie unprocessed coal andkerosene included normative guidance guidelines indoor air quality householdfuel combustion component captured sdg 712 percentage populationwith primary reliance clean fuels technology5 access basic mobility refers convenient access transport rural context sdg911 convenient access public transport urban context sdg 1121 access mobility rural contextto eradicate poverty communities need connected socioeconomic opportunitiesby roads passable season attract reliable affordable public transportservices many areas safe footpaths footbridges waterways may required inconjunction alternative roads reasons simplification specificemphasis given roads definition based rural access index rai percentage population 2km allseason road equivalent walk 2025mins12since road transport reflects accessibility great majority people ruralcontexts situations another mode water transport dominant thedefinition modified contextualized reflect capture aspects access tomobility shown largest impacts poverty reduction strongcorrelation educational economic health outcomes transport enablerrai widely accepted metric tracking access transport rural areas hasbeen included sdgs sdg indicator 911 proportion rural population livewithin 2 km allseason road component therefore captured sdg911the existing rai methodology relies household level survey data however currentlybeing revised gisbased index exploits advances digital technology aimto cre ...
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    indicator 142 measures relevant part target 14 ensure men women equal rights economic resources well access ownership control land forms last reviewed august 2021 property inheritance natural resources m ...
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# ...
# 243                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 244                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 245                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# Name: definition, dtype: object

# %% [markdown]
# # use tf-idf to do word embedding

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

tfidfvectoriser=TfidfVectorizer()
tfidfvectoriser.fit(df['definition'])
tfidf_vectors=tfidfvectoriser.transform(df['definition'])

#calculate similarity based on the vectors
pairwise_similarities=cosine_similarity(tfidf_vectors.toarray())

# %%
my_vec = pd.DataFrame(tfidf_vectors.toarray())
my_vec.columns = tfidfvectoriser.vocabulary_

# %%
my_vec.columns
# Out:
# Index(['indicator', 'proportion', 'population', 'international', 'poverty',
#        'line', 'defined', 'percentage', 'living', 'less',
#        ...
#        'awaiting', 'dollar', 'developingcountries', 'press', 'andadministered',
#        'indeveloping', 'housingcensus', 'andhousing', 'registers', 'records'],
#       dtype='object', length=4128)

# %% [markdown]
# ### convert similarity to a dataframe

# %%
def similardocs_one(doc_id,similarity_matrix):
    #find the index for the doc_id
    index = df.iloc[doc_id]['Index']
    #initiated related index
    related_index = []
    similar_score = similarity_matrix[doc_id]
    score_sort = np.sort(similar_score)[::-1]
    #find related doc_id, sort from most similar to least similar 
    similar_ix=np.argsort(similarity_matrix[doc_id])[::-1] # sort doc_id from most similar to least 
    #find corresponded index for doc_id
    for ix in similar_ix:
        if ix==doc_id:
            continue
        related_index.append(df.iloc[ix]["Index"])
    #create a dataframe of
    relation_df = pd.DataFrame({'indicator': np.repeat(index, len(related_index)),
                                'related_indicator': related_index,
                                'similarity_score': score_sort[1:]})
    return relation_df

list_of_dataframes = [similardocs_one(x,pairwise_similarities) for x in range(len(df['Index']))]
outcome = pd.concat(list_of_dataframes)

# %%
outcome.shape
# Out:
# (60270, 3)

# %%
outcome[outcome['indicator'] == '1.1.1']
# Out:
#     indicator related_indicator  similarity_score
# 0       1.1.1             1.2.1          0.414994
# 1       1.1.1            10.2.1          0.193975
# 2       1.1.1            10.7.4          0.158748
# 3       1.1.1            16.8.1          0.155508
# 4       1.1.1            16.b.1          0.152244
# 5       1.1.1            10.3.1          0.152244
# 6       1.1.1            16.1.1          0.147457
# 7       1.1.1            16.1.2          0.138353
# 8       1.1.1            16.4.2          0.137039
# 9       1.1.1            10.6.1          0.122047
# 10      1.1.1             8.9.1          0.119202
# 11      1.1.1             7.1.1          0.116192
# 12      1.1.1           17.19.2          0.111769
# 13      1.1.1             1.2.2          0.105804
# 230     1.1.1             3.d.1          0.000000
# 231     1.1.1             3.3.5          0.000000
# 232     1.1.1             4.b.1          0.000000
# 233     1.1.1             5.a.1          0.000000
# 234     1.1.1             8.4.1          0.000000
# 235     1.1.1            8.10.1          0.000000
# 236     1.1.1             3.2.1          0.000000
# 237     1.1.1            12.2.1          0.000000
# 238     1.1.1             9.a.1          0.000000
# 239     1.1.1            10.4.1          0.000000
# 240     1.1.1            10.b.1          0.000000
# 241     1.1.1             2.a.2          0.000000
# 242     1.1.1            11.5.2          0.000000
# 243     1.1.1            11.b.1          0.000000
# 244     1.1.1             9.5.2          0.000000

# %% [markdown]
# ### predict the belonged goal using word embedding result to evaluate the accuracy of word embedding?

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

# %%
# predict the belonged goal by the embedded definition, to check the accuracy of embedding
X_train, X_test, y_train, y_test = train_test_split(tfidf_vectors.toarray(), df['goal_num'], test_size=0.2, random_state=42)
clf = RandomForestClassifier(random_state=123)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
precision_recall_fscore_support(y_test, y_pred, average='weighted')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# (0.579047619047619, 0.44, 0.4321818181818181, None)

# %% [markdown]
# # use bert to do word embeddings and calculate the similarity

# %%
from sentence_transformers import SentenceTransformer
sbert_model = SentenceTransformer('bert-base-nli-mean-tokens')

document_embeddings = sbert_model.encode(df['definition'])

pairwise_similarities=cosine_similarity(document_embeddings)

# %%
list_of_dataframes = [similardocs_one(x,pairwise_similarities) for x in range(len(df['Index']))]
outcome = pd.concat(list_of_dataframes)

# %%
outcome[outcome['indicator'] == '1.1.1']
# Out:
#     indicator related_indicator  similarity_score
# 0       1.1.1            17.2.1          0.791766
# 1       1.1.1            10.a.1          0.767115
# 2       1.1.1           17.12.1          0.743590
# 3       1.1.1            10.c.1          0.738721
# 4       1.1.1            11.6.2          0.703645
# 5       1.1.1            10.2.1          0.698540
# 6       1.1.1             1.b.1          0.680495
# 7       1.1.1           17.19.2          0.660144
# 8       1.1.1             1.2.1          0.651749
# 9       1.1.1            10.4.2          0.650623
# 10      1.1.1            16.5.1          0.640838
# 11      1.1.1            10.7.1          0.637356
# 12      1.1.1             3.2.1          0.630509
# 13      1.1.1           17.18.3          0.626487
# 14      1.1.1            10.7.4          0.622960
# 15      1.1.1             2.3.2          0.618727
# 16      1.1.1             2.3.1          0.616280
# 17      1.1.1             8.3.1          0.615898
# 18      1.1.1            10.5.1          0.613635
# 19      1.1.1             1.a.1          0.607624
# 20      1.1.1             3.4.2          0.604973
# 21      1.1.1            17.6.1          0.599676
# 22      1.1.1            10.1.1          0.595216
# 23      1.1.1             3.a.1          0.594473
# 24      1.1.1            11.4.1          0.594241
# 25      1.1.1             2.1.1          0.593760
# 26      1.1.1             8.1.1          0.591940
# 27      1.1.1            16.1.2          0.591203
# 28      1.1.1            17.1.1          0.587910
# 29      1.1.1           16.10.2          0.587614
# 30      1.1.1             4.b.1          0.586616
# 31      1.1.1             3.9.3          0.583485
# 32      1.1.1             4.c.1          0.580707
# 33      1.1.1             3.4.1          0.580519
# 34      1.1.1            11.5.2          0.580408
# 35      1.1.1             6.a.1          0.579379
# 180     1.1.1             3.7.1          0.421668
# 181     1.1.1             8.7.1          0.421202
# 182     1.1.1             8.b.1          0.418933
# 183     1.1.1             5.3.1          0.418466
# 184     1.1.1            14.7.1          0.417039
# 185     1.1.1             3.d.1          0.416005
# 186     1.1.1             2.5.2          0.415476
# 187     1.1.1            14.c.1          0.412628
# 188     1.1.1             4.2.2          0.411844
# 189     1.1.1             5.6.2          0.404686
# 190     1.1.1            11.a.1          0.404368
# 191     1.1.1             3.b.3          0.404277
# 192     1.1.1             7.1.2          0.400039
# 193     1.1.1             4.2.1          0.399909
# 194     1.1.1             3.d.2          0.399891
# 195     1.1.1             6.6.1          0.399390
# 196     1.1.1            14.2.1          0.398558
# 197     1.1.1            15.4.2          0.397998
# 198     1.1.1            11.3.2          0.396194
# 199     1.1.1             5.1.1          0.394653
# 200     1.1.1             9.b.1          0.394435
# 201     1.1.1            17.8.1          0.392108
# 202     1.1.1            15.1.2          0.390862
# 203     1.1.1            16.3.1          0.389719
# 204     1.1.1            16.1.4          0.389263
# 205     1.1.1            11.b.1          0.388976
# 206     1.1.1             5.5.2          0.387741
# 207     1.1.1             4.4.1          0.387701
# 208     1.1.1            15.8.1          0.386564
# 209     1.1.1             1.4.2          0.386287
# 210     1.1.1            16.a.1          0.385286
# 211     1.1.1             6.5.2          0.384421
# 212     1.1.1            15.6.1          0.372454
# 213     1.1.1             2.5.1          0.371244
# 214     1.1.1            13.1.2          0.366753
# 215     1.1.1             1.5.3          0.366753
# 216     1.1.1            11.7.2          0.366678
# 217     1.1.1            14.5.1          0.359191
# 218     1.1.1             5.2.2          0.357235
# 219     1.1.1            16.4.2          0.356908
# 220     1.1.1            14.b.1          0.355968
# 221     1.1.1           16.10.1          0.354119
# 222     1.1.1             3.3.4          0.353421
# 223     1.1.1            10.7.2          0.353300
# 224     1.1.1            10.6.1          0.352044
# 225     1.1.1             9.2.2          0.349378
# 226     1.1.1             6.b.1          0.348010
# 227     1.1.1            15.c.1          0.347735
# 228     1.1.1            15.7.1          0.347735
# 229     1.1.1            15.4.1          0.342985
# 230     1.1.1           17.11.1          0.333666
# 231     1.1.1             8.8.2          0.329858
# 232     1.1.1             5.2.1          0.327134
# 233     1.1.1            16.9.1          0.323177
# 234     1.1.1           17.16.1          0.321423
# 235     1.1.1            14.6.1          0.321132
# 236     1.1.1           17.15.1          0.311030
# 237     1.1.1             3.1.2          0.310938
# 238     1.1.1             6.1.1          0.307194
# 239     1.1.1             5.6.1          0.299435
# 240     1.1.1            16.2.3          0.296572
# 241     1.1.1            13.2.1          0.295609
# 242     1.1.1             6.2.1          0.292351
# 243     1.1.1             5.b.1          0.279984
# 244     1.1.1            15.1.1          0.275574

# %%
X_train, X_test, y_train, y_test = train_test_split(document_embeddings, df['goal_num'], test_size=0.2, random_state=42)
clf = RandomForestClassifier(random_state=123)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
precision_recall_fscore_support(y_test, y_pred, average='weighted')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# (0.5550732600732601, 0.44, 0.44217179311916155, None)

# %% [markdown]
# ## using doc2vec

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/hannahz/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# get the data into the format neede for doc2vec (tagged data )
tagged_data = [TaggedDocument(words=word_tokenize(doc), tags=[i]) for i, doc in enumerate(df['definition'])]

# %%
model = Doc2Vec(vector_size = 300, alpha = 0.025,min_count=5,dm =1,epochs = 50) #alpha learning rate, 
model.build_vocab(tagged_data)

#train the model
model.train(tagged_data,total_examples=model.corpus_count,# number of documents 246
                        epochs=model.epochs)

#gain the word embeddings from the model
document_embeddings=np.zeros((246,300))
for i in range(len(document_embeddings)):
    document_embeddings[i]= model.docvecs[i]
# Out:
# <ipython-input-12-3938c60db6a3>:11: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model.docvecs[i]

# %%
document_embeddings
# Out:
# array([[ 0.0457717 ,  0.03620621,  0.03652849, ...,  0.04891679,
#          0.03314833,  0.01949126],
#        [ 0.18528946,  0.1902861 ,  0.03061791, ...,  0.12184305,
#          0.27267104,  0.08396541],
#        [ 0.21567142,  0.32836252, -0.0282975 , ...,  0.12741885,
#          0.01630357, -0.1264587 ],
#        ...,
#        [ 0.02065087,  0.32834831,  0.13657658, ..., -0.15822282,
#         -0.02846087, -0.12677099],
#        [-0.1197174 ,  0.12338128, -0.05176521, ..., -0.11801478,
#          0.0294875 , -0.0245464 ],
#        [ 0.01328554,  0.10891927,  0.01199636, ...,  0.02036428,
#         -0.00905238,  0.04833864]])

# %%
pairwise_similarities=cosine_similarity(document_embeddings)

list_of_dataframes = [similardocs_one(x,pairwise_similarities) for x in range(len(df['Index']))]
outcome = pd.concat(list_of_dataframes)

# %%
outcome[outcome['indicator'] == '1.1.1']
# Out:
#     indicator related_indicator  similarity_score
# 0       1.1.1             1.2.1          0.835552
# 1       1.1.1            11.1.1          0.789279
# 2       1.1.1             8.5.2          0.702510
# 3       1.1.1            11.6.2          0.689911
# 4       1.1.1             3.3.1          0.675195
# 5       1.1.1            10.2.1          0.672549
# 6       1.1.1             3.3.2          0.666410
# 7       1.1.1             3.3.3          0.661915
# 8       1.1.1             3.3.5          0.650812
# 9       1.1.1            10.4.2          0.644448
# 10      1.1.1            17.3.2          0.642102
# 11      1.1.1             3.6.1          0.639407
# 12      1.1.1            10.a.1          0.636245
# 13      1.1.1             9.1.1          0.635926
# 14      1.1.1             9.c.1          0.631515
# 15      1.1.1            13.1.1          0.628959
# 16      1.1.1             1.5.1          0.625579
# 17      1.1.1             3.1.1          0.624112
# 18      1.1.1             1.b.1          0.609206
# 19      1.1.1           17.12.1          0.604119
# 20      1.1.1             4.2.2          0.597362
# 21      1.1.1             3.4.2          0.592165
# 22      1.1.1            11.5.1          0.591264
# 23      1.1.1            16.4.2          0.584834
# 24      1.1.1             3.9.3          0.580724
# 25      1.1.1             3.2.2          0.578386
# 26      1.1.1             3.2.1          0.569059
# 27      1.1.1             1.2.2          0.565403
# 28      1.1.1            16.1.4          0.558854
# 29      1.1.1            10.1.1          0.557967
# 30      1.1.1             8.6.1          0.556625
# 31      1.1.1            8.10.1          0.556411
# 32      1.1.1             2.5.2          0.555871
# 33      1.1.1             9.5.2          0.550650
# 34      1.1.1             7.1.1          0.546839
# 35      1.1.1             3.8.1          0.541139
# 179     1.1.1           17.15.1          0.168447
# 180     1.1.1            15.a.1          0.167330
# 181     1.1.1             1.3.1          0.157560
# 182     1.1.1            16.b.1          0.150608
# 183     1.1.1            10.7.3          0.150028
# 184     1.1.1             3.5.2          0.137481
# 185     1.1.1             2.3.1          0.133362
# 186     1.1.1            17.1.1          0.132873
# 187     1.1.1            11.3.2          0.131267
# 188     1.1.1           17.17.1          0.130126
# 189     1.1.1            10.3.1          0.129711
# 190     1.1.1             2.3.2          0.124514
# 191     1.1.1            16.6.2          0.119025
# 192     1.1.1            15.4.1          0.117104
# 193     1.1.1             5.3.2          0.116869
# 194     1.1.1             5.1.1          0.104562
# 195     1.1.1            15.1.2          0.104028
# 196     1.1.1            16.a.1          0.097731
# 197     1.1.1            10.7.2          0.097425
# 198     1.1.1            15.8.1          0.091083
# 199     1.1.1            12.8.1          0.086097
# 200     1.1.1            11.2.1          0.078213
# 201     1.1.1            13.3.1          0.077238
# 202     1.1.1            15.9.1          0.067078
# 203     1.1.1            12.4.2          0.065607
# 204     1.1.1            10.5.1          0.059509
# 205     1.1.1            16.2.2          0.059007
# 206     1.1.1            17.6.1          0.055474
# 207     1.1.1            12.b.1          0.050544
# 208     1.1.1            15.3.1          0.040753
# 209     1.1.1            14.5.1          0.019886
# 210     1.1.1            13.b.1          0.019478
# 211     1.1.1             8.8.2          0.014293
# 212     1.1.1             6.4.2          0.011765
# 213     1.1.1            14.b.1         -0.000170
# 214     1.1.1           17.14.1         -0.003604
# 215     1.1.1           16.10.1         -0.005078
# 216     1.1.1            14.c.1         -0.030088
# 217     1.1.1             6.4.1         -0.035683
# 218     1.1.1            16.4.1         -0.037916
# 219     1.1.1             7.a.1         -0.040244
# 220     1.1.1            14.2.1         -0.058837
# 221     1.1.1            11.7.1         -0.060965
# 222     1.1.1             3.d.1         -0.070852
# 223     1.1.1            12.6.1         -0.071913
# 224     1.1.1             2.4.1         -0.088491
# 225     1.1.1             6.6.1         -0.091456
# 226     1.1.1            15.2.1         -0.094135
# 227     1.1.1             1.4.2         -0.099635
# 228     1.1.1            17.7.1         -0.105495
# 229     1.1.1            12.7.1         -0.105652
# 230     1.1.1            14.3.1         -0.118181
# 231     1.1.1             6.5.1         -0.119989
# 232     1.1.1           17.19.1         -0.132812
# 233     1.1.1             5.a.2         -0.132906
# 234     1.1.1             2.5.1         -0.138882
# 235     1.1.1            13.2.2         -0.145502
# 236     1.1.1           16.10.2         -0.155794
# 237     1.1.1            13.a.1         -0.157132
# 238     1.1.1             6.3.2         -0.174650
# 239     1.1.1            14.1.1         -0.178967
# 240     1.1.1            15.6.1         -0.179179
# 241     1.1.1            12.4.1         -0.232206
# 242     1.1.1            14.a.1         -0.315204
# 243     1.1.1            14.4.1         -0.326301
# 244     1.1.1             6.5.2         -0.352158

# %%
X_train, X_test, y_train, y_test = train_test_split(document_embeddings, df['goal_num'], test_size=0.2, random_state=42)
clf = RandomForestClassifier(random_state=123)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
precision_recall_fscore_support(y_test, y_pred, average='weighted')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# (0.5855555555555556, 0.46, 0.4632307692307693, None)

# %% [markdown]
# ## some try out code
# ## clean indicator column

# %%
#remove \n
df['Indicator'] = df['Indicator'].replace(r'\n','', regex=True) 
#remove multiple whitespace
df['Indicator'] = df['Indicator'].replace('\s+', ' ', regex=True)
#remove white space in the beginning and end
df['Indicator'] = df['Indicator'].str.strip()

df['Indicator']=df['Indicator'].apply(lambda x: " ".join(re.sub(r'[^a-zA-Z]','',w).lower() for w in x.split() if re.sub(r'[^a-zA-Z]',' ',w).lower() not in stop_words_l) )
#remove white space 
df['Indicator'] = df['Indicator'].replace('\s+', ' ', regex=True)

# %%
# select the target index out of index eg 1.1, 1.2
index_num = df['Index']
df['target_num'] = [num[:-2] for num in index_num]

# %%
tagged_data = [TaggedDocument(words=word_tokenize(doc), tags=[i]) for i, doc in enumerate(df['Indicator'])]

# %%
len(tagged_data)
# Out:
# 246

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

# %%
f1score = []
model = []
for vector_size in [500]:
    for alpha in[0.025]:
        for min_count in [5]:
            for dm in [1]:
                for epochs in [500]:
                    #record the model parameter
                    model.append(f'vector_size:{vector_size},alpha:{alpha},min_count:{min_count},dm:{dm},epochs:{epochs}')
                    #initiate the model
                    model_d2v = Doc2Vec(vector_size = vector_size ,alpha = alpha, min_count = min_count, dm = dm, epochs = epochs) #alpha learning rate, 
                    model_d2v.build_vocab(tagged_data)
                    #train the model
                    model_d2v.train(tagged_data,
                        total_examples=model_d2v.corpus_count,# number of documents 246
                        epochs=model_d2v.epochs)
                    #gain the word embeddings from the model
                    document_embeddings=np.zeros((df.shape[0],vector_size))
                    for i in range(len(document_embeddings)):
                        document_embeddings[i]= model_d2v.docvecs[i]
                    # evaluate the model
                    X_train, X_test, y_train, y_test = train_test_split(document_embeddings, df['goal_num'], test_size=0.33, random_state=42)
                    clf = RandomForestClassifier(max_depth=100, random_state=123)
                    clf.fit(X_train, y_train)
                    y_pred = clf.predict(X_test)
                    f1score.append(f1_score(y_test, y_pred, average='weighted'))

model_score = pd.DataFrame({'model' : model,'f1score' : f1score})
model_score
# Out:
# <ipython-input-260-c3b2849b8425>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
#                                                      model   f1score
# 0  vector_size:500,alpha:0.025,min_count:5,dm:1,epochs:500  0.178189

# %%
f1score = []
model = []
for vector_size in [100,200,300]:
    for alpha in[0.020, 0.025]:
        for min_count in [1,3,5]:
            for dm in [0, 1]:
                for epochs in [20,100,500,1000]:
                    #record the model parameter
                    model.append(f'vector_size:{vector_size},alpha:{alpha},min_count:{min_count},dm:{dm},epochs:{epochs}')
                    #initiate the model
                    model_d2v = Doc2Vec(vector_size = vector_size ,alpha = alpha, min_count = min_count, dm = dm, epochs = epochs) #alpha learning rate, 
                    model_d2v.build_vocab(tagged_data)
                    #train the model
                    model_d2v.train(tagged_data,
                        total_examples=model_d2v.corpus_count,# number of documents 246
                        epochs=model_d2v.epochs)
                    #gain the word embeddings from the model
                    document_embeddings=np.zeros((df.shape[0],vector_size))
                    for i in range(len(document_embeddings)):
                        document_embeddings[i]= model_d2v.docvecs[i]
                    # evaluate the model
                    X_train, X_test, y_train, y_test = train_test_split(document_embeddings, df['goal_num'], test_size=0.33, random_state=42)
                    clf = RandomForestClassifier(max_depth=2, random_state=123)
                    clf.fit(X_train, y_train)
                    y_pred = clf.predict(X_test)
                    f1score.append(f1_score(y_test, y_pred, average='weighted'))

model_score = pd.DataFrame({'model' : model,'f1score' : f1score})
model_score
# Out:
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
# <ipython-input-192-6fbca14763ca>:20: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]
#                                                         model   f1score
# 0       vector_size:100,alpha:0.02,min_count:1,dm:0,epochs:20  0.000000
# 1      vector_size:100,alpha:0.02,min_count:1,dm:0,epochs:100  0.000938
# 2      vector_size:100,alpha:0.02,min_count:1,dm:0,epochs:500  0.000610
# 3     vector_size:100,alpha:0.02,min_count:1,dm:0,epochs:1000  0.000787
# 4       vector_size:100,alpha:0.02,min_count:1,dm:1,epochs:20  0.000000
# 5      vector_size:100,alpha:0.02,min_count:1,dm:1,epochs:100  0.000000
# 6      vector_size:100,alpha:0.02,min_count:1,dm:1,epochs:500  0.000542
# 7     vector_size:100,alpha:0.02,min_count:1,dm:1,epochs:1000  0.000530
# 8       vector_size:100,alpha:0.02,min_count:3,dm:0,epochs:20  0.000000
# 9      vector_size:100,alpha:0.02,min_count:3,dm:0,epochs:100  0.000678
# 10     vector_size:100,alpha:0.02,min_count:3,dm:0,epochs:500  0.000610
# 11    vector_size:100,alpha:0.02,min_count:3,dm:0,epochs:1000  0.000841
# 12      vector_size:100,alpha:0.02,min_count:3,dm:1,epochs:20  0.000000
# 13     vector_size:100,alpha:0.02,min_count:3,dm:1,epochs:100  0.000000
# 14     vector_size:100,alpha:0.02,min_count:3,dm:1,epochs:500  0.000421
# 15    vector_size:100,alpha:0.02,min_count:3,dm:1,epochs:1000  0.000460
# 16      vector_size:100,alpha:0.02,min_count:5,dm:0,epochs:20  0.001060
# 17     vector_size:100,alpha:0.02,min_count:5,dm:0,epochs:100  0.001161
# 18     vector_size:100,alpha:0.02,min_count:5,dm:0,epochs:500  0.000659
# 19    vector_size:100,alpha:0.02,min_count:5,dm:0,epochs:1000  0.000000
# 20      vector_size:100,alpha:0.02,min_count:5,dm:1,epochs:20  0.000000
# 21     vector_size:100,alpha:0.02,min_count:5,dm:1,epochs:100  0.000739
# 22     vector_size:100,alpha:0.02,min_count:5,dm:1,epochs:500  0.012873
# 23    vector_size:100,alpha:0.02,min_count:5,dm:1,epochs:1000  0.000519
# 24     vector_size:100,alpha:0.025,min_count:1,dm:0,epochs:20  0.000000
# 25    vector_size:100,alpha:0.025,min_count:1,dm:0,epochs:100  0.000659
# 26    vector_size:100,alpha:0.025,min_count:1,dm:0,epochs:500  0.000498
# 27   vector_size:100,alpha:0.025,min_count:1,dm:0,epochs:1000  0.000000
# 28     vector_size:100,alpha:0.025,min_count:1,dm:1,epochs:20  0.000000
# 29    vector_size:100,alpha:0.025,min_count:1,dm:1,epochs:100  0.000000
# 30    vector_size:100,alpha:0.025,min_count:1,dm:1,epochs:500  0.000519
# 31   vector_size:100,alpha:0.025,min_count:1,dm:1,epochs:1000  0.000519
# 32     vector_size:100,alpha:0.025,min_count:3,dm:0,epochs:20  0.000000
# 33    vector_size:100,alpha:0.025,min_count:3,dm:0,epochs:100  0.000871
# 34    vector_size:100,alpha:0.025,min_count:3,dm:0,epochs:500  0.000610
# 35   vector_size:100,alpha:0.025,min_count:3,dm:0,epochs:1000  0.000841
# 36     vector_size:100,alpha:0.025,min_count:3,dm:1,epochs:20  0.000000
# 37    vector_size:100,alpha:0.025,min_count:3,dm:1,epochs:100  0.000000
# 38    vector_size:100,alpha:0.025,min_count:3,dm:1,epochs:500  0.000436
# 39   vector_size:100,alpha:0.025,min_count:3,dm:1,epochs:1000  0.000508
# 40     vector_size:100,alpha:0.025,min_count:5,dm:0,epochs:20  0.000000
# 41    vector_size:100,alpha:0.025,min_count:5,dm:0,epochs:100  0.000871
# 42    vector_size:100,alpha:0.025,min_count:5,dm:0,epochs:500  0.000530
# 43   vector_size:100,alpha:0.025,min_count:5,dm:0,epochs:1000  0.000813
# 44     vector_size:100,alpha:0.025,min_count:5,dm:1,epochs:20  0.000000
# 45    vector_size:100,alpha:0.025,min_count:5,dm:1,epochs:100  0.000000
# 46    vector_size:100,alpha:0.025,min_count:5,dm:1,epochs:500  0.000581
# 47   vector_size:100,alpha:0.025,min_count:5,dm:1,epochs:1000  0.000469
# 48      vector_size:200,alpha:0.02,min_count:1,dm:0,epochs:20  0.000000
# 49     vector_size:200,alpha:0.02,min_count:1,dm:0,epochs:100  0.001284
# 50     vector_size:200,alpha:0.02,min_count:1,dm:0,epochs:500  0.000938
# 51    vector_size:200,alpha:0.02,min_count:1,dm:0,epochs:1000  0.001435
# 52      vector_size:200,alpha:0.02,min_count:1,dm:1,epochs:20  0.000000
# 53     vector_size:200,alpha:0.02,min_count:1,dm:1,epochs:100  0.001161
# 54     vector_size:200,alpha:0.02,min_count:1,dm:1,epochs:500  0.000595
# 55    vector_size:200,alpha:0.02,min_count:1,dm:1,epochs:1000  0.000581
# 56      vector_size:200,alpha:0.02,min_count:3,dm:0,epochs:20  0.000000
# 57     vector_size:200,alpha:0.02,min_count:3,dm:0,epochs:100  0.001109
# 58     vector_size:200,alpha:0.02,min_count:3,dm:0,epochs:500  0.001355
# 59    vector_size:200,alpha:0.02,min_count:3,dm:0,epochs:1000  0.001161
# 60      vector_size:200,alpha:0.02,min_count:3,dm:1,epochs:20  0.000000
# 61     vector_size:200,alpha:0.02,min_count:3,dm:1,epochs:100  0.000000
# 62     vector_size:200,alpha:0.02,min_count:3,dm:1,epochs:500  0.000567
# 63    vector_size:200,alpha:0.02,min_count:3,dm:1,epochs:1000  0.000813
# 64      vector_size:200,alpha:0.02,min_count:5,dm:0,epochs:20  0.000813
# 65     vector_size:200,alpha:0.02,min_count:5,dm:0,epochs:100  0.012195
# 66     vector_size:200,alpha:0.02,min_count:5,dm:0,epochs:500  0.002439
# 67    vector_size:200,alpha:0.02,min_count:5,dm:0,epochs:1000  0.002217
# 68      vector_size:200,alpha:0.02,min_count:5,dm:1,epochs:20  0.000000
# 69     vector_size:200,alpha:0.02,min_count:5,dm:1,epochs:100  0.001524
# 70     vector_size:200,alpha:0.02,min_count:5,dm:1,epochs:500  0.000000
# 71    vector_size:200,alpha:0.02,min_count:5,dm:1,epochs:1000  0.000554
# 72     vector_size:200,alpha:0.025,min_count:1,dm:0,epochs:20  0.000000
# 73    vector_size:200,alpha:0.025,min_count:1,dm:0,epochs:100  0.001109
# 74    vector_size:200,alpha:0.025,min_count:1,dm:0,epochs:500  0.001626
# 75   vector_size:200,alpha:0.025,min_count:1,dm:0,epochs:1000  0.003484
# 76     vector_size:200,alpha:0.025,min_count:1,dm:1,epochs:20  0.000000
# 77    vector_size:200,alpha:0.025,min_count:1,dm:1,epochs:100  0.001742
# 78    vector_size:200,alpha:0.025,min_count:1,dm:1,epochs:500  0.012703
# 79   vector_size:200,alpha:0.025,min_count:1,dm:1,epochs:1000  0.000488
# 80     vector_size:200,alpha:0.025,min_count:3,dm:0,epochs:20  0.000000
# 81    vector_size:200,alpha:0.025,min_count:3,dm:0,epochs:100  0.001626
# 82    vector_size:200,alpha:0.025,min_count:3,dm:0,epochs:500  0.001060
# 83   vector_size:200,alpha:0.025,min_count:3,dm:0,epochs:1000  0.001220
# 84     vector_size:200,alpha:0.025,min_count:3,dm:1,epochs:20  0.000000
# 85    vector_size:200,alpha:0.025,min_count:3,dm:1,epochs:100  0.000739
# 86    vector_size:200,alpha:0.025,min_count:3,dm:1,epochs:500  0.000530
# 87   vector_size:200,alpha:0.025,min_count:3,dm:1,epochs:1000  0.000000
# 88     vector_size:200,alpha:0.025,min_count:5,dm:0,epochs:20  0.000000
# 89    vector_size:200,alpha:0.025,min_count:5,dm:0,epochs:100  0.000000
# 90    vector_size:200,alpha:0.025,min_count:5,dm:0,epochs:500  0.001435
# 91   vector_size:200,alpha:0.025,min_count:5,dm:0,epochs:1000  0.002033
# 92     vector_size:200,alpha:0.025,min_count:5,dm:1,epochs:20  0.000000
# 93    vector_size:200,alpha:0.025,min_count:5,dm:1,epochs:100  0.001109
# 94    vector_size:200,alpha:0.025,min_count:5,dm:1,epochs:500  0.000813
# 95   vector_size:200,alpha:0.025,min_count:5,dm:1,epochs:1000  0.000000
# 96      vector_size:300,alpha:0.02,min_count:1,dm:0,epochs:20  0.000000
# 97     vector_size:300,alpha:0.02,min_count:1,dm:0,epochs:100  0.001876
# 98     vector_size:300,alpha:0.02,min_count:1,dm:0,epochs:500  0.001626
# 99    vector_size:300,alpha:0.02,min_count:1,dm:0,epochs:1000  0.002217
# 100     vector_size:300,alpha:0.02,min_count:1,dm:1,epochs:20  0.000000
# 101    vector_size:300,alpha:0.02,min_count:1,dm:1,epochs:100  0.000841
# 102    vector_size:300,alpha:0.02,min_count:1,dm:1,epochs:500  0.001220
# 103   vector_size:300,alpha:0.02,min_count:1,dm:1,epochs:1000  0.000554
# 104     vector_size:300,alpha:0.02,min_count:3,dm:0,epochs:20  0.000762
# 105    vector_size:300,alpha:0.02,min_count:3,dm:0,epochs:100  0.001876
# 106    vector_size:300,alpha:0.02,min_count:3,dm:0,epochs:500  0.001355
# 107   vector_size:300,alpha:0.02,min_count:3,dm:0,epochs:1000  0.001355
# 108     vector_size:300,alpha:0.02,min_count:3,dm:1,epochs:20  0.012195
# 109    vector_size:300,alpha:0.02,min_count:3,dm:1,epochs:100  0.000000
# 110    vector_size:300,alpha:0.02,min_count:3,dm:1,epochs:500  0.000508
# 111   vector_size:300,alpha:0.02,min_count:3,dm:1,epochs:1000  0.000519
# 112     vector_size:300,alpha:0.02,min_count:5,dm:0,epochs:20  0.000000
# 113    vector_size:300,alpha:0.02,min_count:5,dm:0,epochs:100  0.004065
# 114    vector_size:300,alpha:0.02,min_count:5,dm:0,epochs:500  0.001016
# 115   vector_size:300,alpha:0.02,min_count:5,dm:0,epochs:1000  0.001355
# 116     vector_size:300,alpha:0.02,min_count:5,dm:1,epochs:20  0.000000
# 117    vector_size:300,alpha:0.02,min_count:5,dm:1,epochs:100  0.002217
# 118    vector_size:300,alpha:0.02,min_count:5,dm:1,epochs:500  0.001626
# 119   vector_size:300,alpha:0.02,min_count:5,dm:1,epochs:1000  0.000000
# 120    vector_size:300,alpha:0.025,min_count:1,dm:0,epochs:20  0.000000
# 121   vector_size:300,alpha:0.025,min_count:1,dm:0,epochs:100  0.000610
# 122   vector_size:300,alpha:0.025,min_count:1,dm:0,epochs:500  0.012195
# 123  vector_size:300,alpha:0.025,min_count:1,dm:0,epochs:1000  0.001016
# 124    vector_size:300,alpha:0.025,min_count:1,dm:1,epochs:20  0.008130
# 125   vector_size:300,alpha:0.025,min_count:1,dm:1,epochs:100  0.000581
# 126   vector_size:300,alpha:0.025,min_count:1,dm:1,epochs:500  0.000508
# 127  vector_size:300,alpha:0.025,min_count:1,dm:1,epochs:1000  0.001524
# 128    vector_size:300,alpha:0.025,min_count:3,dm:0,epochs:20  0.000000
# 129   vector_size:300,alpha:0.025,min_count:3,dm:0,epochs:100  0.002710
# 130   vector_size:300,alpha:0.025,min_count:3,dm:0,epochs:500  0.001626
# 131  vector_size:300,alpha:0.025,min_count:3,dm:0,epochs:1000  0.000976
# 132    vector_size:300,alpha:0.025,min_count:3,dm:1,epochs:20  0.000000
# 133   vector_size:300,alpha:0.025,min_count:3,dm:1,epochs:100  0.000000
# 134   vector_size:300,alpha:0.025,min_count:3,dm:1,epochs:500  0.000903
# 135  vector_size:300,alpha:0.025,min_count:3,dm:1,epochs:1000  0.000554
# 136    vector_size:300,alpha:0.025,min_count:5,dm:0,epochs:20  0.001161
# 137   vector_size:300,alpha:0.025,min_count:5,dm:0,epochs:100  0.000000
# 138   vector_size:300,alpha:0.025,min_count:5,dm:0,epochs:500  0.001284
# 139  vector_size:300,alpha:0.025,min_count:5,dm:0,epochs:1000  0.001220
# 140    vector_size:300,alpha:0.025,min_count:5,dm:1,epochs:20  0.000000
# 141   vector_size:300,alpha:0.025,min_count:5,dm:1,epochs:100  0.001524
# 142   vector_size:300,alpha:0.025,min_count:5,dm:1,epochs:500  0.000508
# 143  vector_size:300,alpha:0.025,min_count:5,dm:1,epochs:1000  0.000519

# %%
model_score
# Out:
#                                                         model   f1score
# 0       vector_size:100,alpha:0.02,min_count:1,dm:0,epochs:20  0.000000
# 1      vector_size:100,alpha:0.02,min_count:1,dm:0,epochs:100  0.000938
# 2      vector_size:100,alpha:0.02,min_count:1,dm:0,epochs:500  0.000610
# 3     vector_size:100,alpha:0.02,min_count:1,dm:0,epochs:1000  0.000787
# 4       vector_size:100,alpha:0.02,min_count:1,dm:1,epochs:20  0.000000
# 5      vector_size:100,alpha:0.02,min_count:1,dm:1,epochs:100  0.000000
# 6      vector_size:100,alpha:0.02,min_count:1,dm:1,epochs:500  0.000542
# 7     vector_size:100,alpha:0.02,min_count:1,dm:1,epochs:1000  0.000530
# 8       vector_size:100,alpha:0.02,min_count:3,dm:0,epochs:20  0.000000
# 9      vector_size:100,alpha:0.02,min_count:3,dm:0,epochs:100  0.000678
# 10     vector_size:100,alpha:0.02,min_count:3,dm:0,epochs:500  0.000610
# 11    vector_size:100,alpha:0.02,min_count:3,dm:0,epochs:1000  0.000841
# 12      vector_size:100,alpha:0.02,min_count:3,dm:1,epochs:20  0.000000
# 13     vector_size:100,alpha:0.02,min_count:3,dm:1,epochs:100  0.000000
# 14     vector_size:100,alpha:0.02,min_count:3,dm:1,epochs:500  0.000421
# 15    vector_size:100,alpha:0.02,min_count:3,dm:1,epochs:1000  0.000460
# 16      vector_size:100,alpha:0.02,min_count:5,dm:0,epochs:20  0.001060
# 17     vector_size:100,alpha:0.02,min_count:5,dm:0,epochs:100  0.001161
# 18     vector_size:100,alpha:0.02,min_count:5,dm:0,epochs:500  0.000659
# 19    vector_size:100,alpha:0.02,min_count:5,dm:0,epochs:1000  0.000000
# 20      vector_size:100,alpha:0.02,min_count:5,dm:1,epochs:20  0.000000
# 21     vector_size:100,alpha:0.02,min_count:5,dm:1,epochs:100  0.000739
# 22     vector_size:100,alpha:0.02,min_count:5,dm:1,epochs:500  0.012873
# 23    vector_size:100,alpha:0.02,min_count:5,dm:1,epochs:1000  0.000519
# 24     vector_size:100,alpha:0.025,min_count:1,dm:0,epochs:20  0.000000
# 25    vector_size:100,alpha:0.025,min_count:1,dm:0,epochs:100  0.000659
# 26    vector_size:100,alpha:0.025,min_count:1,dm:0,epochs:500  0.000498
# 27   vector_size:100,alpha:0.025,min_count:1,dm:0,epochs:1000  0.000000
# 28     vector_size:100,alpha:0.025,min_count:1,dm:1,epochs:20  0.000000
# 29    vector_size:100,alpha:0.025,min_count:1,dm:1,epochs:100  0.000000
# 30    vector_size:100,alpha:0.025,min_count:1,dm:1,epochs:500  0.000519
# 31   vector_size:100,alpha:0.025,min_count:1,dm:1,epochs:1000  0.000519
# 32     vector_size:100,alpha:0.025,min_count:3,dm:0,epochs:20  0.000000
# 33    vector_size:100,alpha:0.025,min_count:3,dm:0,epochs:100  0.000871
# 34    vector_size:100,alpha:0.025,min_count:3,dm:0,epochs:500  0.000610
# 35   vector_size:100,alpha:0.025,min_count:3,dm:0,epochs:1000  0.000841
# 36     vector_size:100,alpha:0.025,min_count:3,dm:1,epochs:20  0.000000
# 37    vector_size:100,alpha:0.025,min_count:3,dm:1,epochs:100  0.000000
# 38    vector_size:100,alpha:0.025,min_count:3,dm:1,epochs:500  0.000436
# 39   vector_size:100,alpha:0.025,min_count:3,dm:1,epochs:1000  0.000508
# 40     vector_size:100,alpha:0.025,min_count:5,dm:0,epochs:20  0.000000
# 41    vector_size:100,alpha:0.025,min_count:5,dm:0,epochs:100  0.000871
# 42    vector_size:100,alpha:0.025,min_count:5,dm:0,epochs:500  0.000530
# 43   vector_size:100,alpha:0.025,min_count:5,dm:0,epochs:1000  0.000813
# 44     vector_size:100,alpha:0.025,min_count:5,dm:1,epochs:20  0.000000
# 45    vector_size:100,alpha:0.025,min_count:5,dm:1,epochs:100  0.000000
# 46    vector_size:100,alpha:0.025,min_count:5,dm:1,epochs:500  0.000581
# 47   vector_size:100,alpha:0.025,min_count:5,dm:1,epochs:1000  0.000469
# 48      vector_size:200,alpha:0.02,min_count:1,dm:0,epochs:20  0.000000
# 49     vector_size:200,alpha:0.02,min_count:1,dm:0,epochs:100  0.001284
# 50     vector_size:200,alpha:0.02,min_count:1,dm:0,epochs:500  0.000938
# 51    vector_size:200,alpha:0.02,min_count:1,dm:0,epochs:1000  0.001435
# 52      vector_size:200,alpha:0.02,min_count:1,dm:1,epochs:20  0.000000
# 53     vector_size:200,alpha:0.02,min_count:1,dm:1,epochs:100  0.001161
# 54     vector_size:200,alpha:0.02,min_count:1,dm:1,epochs:500  0.000595
# 55    vector_size:200,alpha:0.02,min_count:1,dm:1,epochs:1000  0.000581
# 56      vector_size:200,alpha:0.02,min_count:3,dm:0,epochs:20  0.000000
# 57     vector_size:200,alpha:0.02,min_count:3,dm:0,epochs:100  0.001109
# 58     vector_size:200,alpha:0.02,min_count:3,dm:0,epochs:500  0.001355
# 59    vector_size:200,alpha:0.02,min_count:3,dm:0,epochs:1000  0.001161
# 60      vector_size:200,alpha:0.02,min_count:3,dm:1,epochs:20  0.000000
# 61     vector_size:200,alpha:0.02,min_count:3,dm:1,epochs:100  0.000000
# 62     vector_size:200,alpha:0.02,min_count:3,dm:1,epochs:500  0.000567
# 63    vector_size:200,alpha:0.02,min_count:3,dm:1,epochs:1000  0.000813
# 64      vector_size:200,alpha:0.02,min_count:5,dm:0,epochs:20  0.000813
# 65     vector_size:200,alpha:0.02,min_count:5,dm:0,epochs:100  0.012195
# 66     vector_size:200,alpha:0.02,min_count:5,dm:0,epochs:500  0.002439
# 67    vector_size:200,alpha:0.02,min_count:5,dm:0,epochs:1000  0.002217
# 68      vector_size:200,alpha:0.02,min_count:5,dm:1,epochs:20  0.000000
# 69     vector_size:200,alpha:0.02,min_count:5,dm:1,epochs:100  0.001524
# 70     vector_size:200,alpha:0.02,min_count:5,dm:1,epochs:500  0.000000
# 71    vector_size:200,alpha:0.02,min_count:5,dm:1,epochs:1000  0.000554
# 72     vector_size:200,alpha:0.025,min_count:1,dm:0,epochs:20  0.000000
# 73    vector_size:200,alpha:0.025,min_count:1,dm:0,epochs:100  0.001109
# 74    vector_size:200,alpha:0.025,min_count:1,dm:0,epochs:500  0.001626
# 75   vector_size:200,alpha:0.025,min_count:1,dm:0,epochs:1000  0.003484
# 76     vector_size:200,alpha:0.025,min_count:1,dm:1,epochs:20  0.000000
# 77    vector_size:200,alpha:0.025,min_count:1,dm:1,epochs:100  0.001742
# 78    vector_size:200,alpha:0.025,min_count:1,dm:1,epochs:500  0.012703
# 79   vector_size:200,alpha:0.025,min_count:1,dm:1,epochs:1000  0.000488
# 80     vector_size:200,alpha:0.025,min_count:3,dm:0,epochs:20  0.000000
# 81    vector_size:200,alpha:0.025,min_count:3,dm:0,epochs:100  0.001626
# 82    vector_size:200,alpha:0.025,min_count:3,dm:0,epochs:500  0.001060
# 83   vector_size:200,alpha:0.025,min_count:3,dm:0,epochs:1000  0.001220
# 84     vector_size:200,alpha:0.025,min_count:3,dm:1,epochs:20  0.000000
# 85    vector_size:200,alpha:0.025,min_count:3,dm:1,epochs:100  0.000739
# 86    vector_size:200,alpha:0.025,min_count:3,dm:1,epochs:500  0.000530
# 87   vector_size:200,alpha:0.025,min_count:3,dm:1,epochs:1000  0.000000
# 88     vector_size:200,alpha:0.025,min_count:5,dm:0,epochs:20  0.000000
# 89    vector_size:200,alpha:0.025,min_count:5,dm:0,epochs:100  0.000000
# 90    vector_size:200,alpha:0.025,min_count:5,dm:0,epochs:500  0.001435
# 91   vector_size:200,alpha:0.025,min_count:5,dm:0,epochs:1000  0.002033
# 92     vector_size:200,alpha:0.025,min_count:5,dm:1,epochs:20  0.000000
# 93    vector_size:200,alpha:0.025,min_count:5,dm:1,epochs:100  0.001109
# 94    vector_size:200,alpha:0.025,min_count:5,dm:1,epochs:500  0.000813
# 95   vector_size:200,alpha:0.025,min_count:5,dm:1,epochs:1000  0.000000
# 96      vector_size:300,alpha:0.02,min_count:1,dm:0,epochs:20  0.000000
# 97     vector_size:300,alpha:0.02,min_count:1,dm:0,epochs:100  0.001876
# 98     vector_size:300,alpha:0.02,min_count:1,dm:0,epochs:500  0.001626
# 99    vector_size:300,alpha:0.02,min_count:1,dm:0,epochs:1000  0.002217
# 100     vector_size:300,alpha:0.02,min_count:1,dm:1,epochs:20  0.000000
# 101    vector_size:300,alpha:0.02,min_count:1,dm:1,epochs:100  0.000841
# 102    vector_size:300,alpha:0.02,min_count:1,dm:1,epochs:500  0.001220
# 103   vector_size:300,alpha:0.02,min_count:1,dm:1,epochs:1000  0.000554
# 104     vector_size:300,alpha:0.02,min_count:3,dm:0,epochs:20  0.000762
# 105    vector_size:300,alpha:0.02,min_count:3,dm:0,epochs:100  0.001876
# 106    vector_size:300,alpha:0.02,min_count:3,dm:0,epochs:500  0.001355
# 107   vector_size:300,alpha:0.02,min_count:3,dm:0,epochs:1000  0.001355
# 108     vector_size:300,alpha:0.02,min_count:3,dm:1,epochs:20  0.012195
# 109    vector_size:300,alpha:0.02,min_count:3,dm:1,epochs:100  0.000000
# 110    vector_size:300,alpha:0.02,min_count:3,dm:1,epochs:500  0.000508
# 111   vector_size:300,alpha:0.02,min_count:3,dm:1,epochs:1000  0.000519
# 112     vector_size:300,alpha:0.02,min_count:5,dm:0,epochs:20  0.000000
# 113    vector_size:300,alpha:0.02,min_count:5,dm:0,epochs:100  0.004065
# 114    vector_size:300,alpha:0.02,min_count:5,dm:0,epochs:500  0.001016
# 115   vector_size:300,alpha:0.02,min_count:5,dm:0,epochs:1000  0.001355
# 116     vector_size:300,alpha:0.02,min_count:5,dm:1,epochs:20  0.000000
# 117    vector_size:300,alpha:0.02,min_count:5,dm:1,epochs:100  0.002217
# 118    vector_size:300,alpha:0.02,min_count:5,dm:1,epochs:500  0.001626
# 119   vector_size:300,alpha:0.02,min_count:5,dm:1,epochs:1000  0.000000
# 120    vector_size:300,alpha:0.025,min_count:1,dm:0,epochs:20  0.000000
# 121   vector_size:300,alpha:0.025,min_count:1,dm:0,epochs:100  0.000610
# 122   vector_size:300,alpha:0.025,min_count:1,dm:0,epochs:500  0.012195
# 123  vector_size:300,alpha:0.025,min_count:1,dm:0,epochs:1000  0.001016
# 124    vector_size:300,alpha:0.025,min_count:1,dm:1,epochs:20  0.008130
# 125   vector_size:300,alpha:0.025,min_count:1,dm:1,epochs:100  0.000581
# 126   vector_size:300,alpha:0.025,min_count:1,dm:1,epochs:500  0.000508
# 127  vector_size:300,alpha:0.025,min_count:1,dm:1,epochs:1000  0.001524
# 128    vector_size:300,alpha:0.025,min_count:3,dm:0,epochs:20  0.000000
# 129   vector_size:300,alpha:0.025,min_count:3,dm:0,epochs:100  0.002710
# 130   vector_size:300,alpha:0.025,min_count:3,dm:0,epochs:500  0.001626
# 131  vector_size:300,alpha:0.025,min_count:3,dm:0,epochs:1000  0.000976
# 132    vector_size:300,alpha:0.025,min_count:3,dm:1,epochs:20  0.000000
# 133   vector_size:300,alpha:0.025,min_count:3,dm:1,epochs:100  0.000000
# 134   vector_size:300,alpha:0.025,min_count:3,dm:1,epochs:500  0.000903
# 135  vector_size:300,alpha:0.025,min_count:3,dm:1,epochs:1000  0.000554
# 136    vector_size:300,alpha:0.025,min_count:5,dm:0,epochs:20  0.001161
# 137   vector_size:300,alpha:0.025,min_count:5,dm:0,epochs:100  0.000000
# 138   vector_size:300,alpha:0.025,min_count:5,dm:0,epochs:500  0.001284
# 139  vector_size:300,alpha:0.025,min_count:5,dm:0,epochs:1000  0.001220
# 140    vector_size:300,alpha:0.025,min_count:5,dm:1,epochs:20  0.000000
# 141   vector_size:300,alpha:0.025,min_count:5,dm:1,epochs:100  0.001524
# 142   vector_size:300,alpha:0.025,min_count:5,dm:1,epochs:500  0.000508
# 143  vector_size:300,alpha:0.025,min_count:5,dm:1,epochs:1000  0.000519
