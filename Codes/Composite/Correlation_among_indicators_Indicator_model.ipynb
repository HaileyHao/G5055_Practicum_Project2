# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Practicum SDG Networks/Data/pc1s.csv')
df=df.rename(columns={'Unnamed: 0': 'Year'})
df=df.set_index('Year')
df
# Out:
#         13.1.3  13.1.2     8.8.2  ...        16.3.2     2.5.2    15.2.1
# Year                              ...
# 2012  1.038600    -0.5  1.506967  ... -1.549193e+00 -1.527374  2.208392
# 2013  0.325498    -0.5  1.130225  ... -1.161895e+00 -0.579349  1.656294
# 2014  0.484697    -0.5  0.753483  ... -7.745967e-01 -0.342342  1.104196
# 2015  0.242348    -0.5  0.757765  ... -3.872983e-01 -0.816355 -0.009687
# 2016 -1.528274    -0.5 -0.509458  ... -3.551675e-14 -0.342342  1.767445
# 2017  2.749971    -0.5 -0.500895  ...  3.872983e-01 -0.342342 -1.565143
# 2018  0.040330    -0.5 -0.500895  ...  7.745967e-01  1.079695 -1.700510
# 2019 -2.383776     2.5 -1.130225  ...  1.161895e+00  1.316702 -1.685386
# 2020 -0.969394     1.0 -1.506967  ...  1.549193e+00  1.553708 -1.775600
#
# [9 rows x 94 columns]

# %%
correlation=df.corr()
print(correlation)
correlation.to_csv('/content/drive/MyDrive/Colab Notebooks/Practicum SDG Networks/Data/Correlation_among_indicators_Indicator_model.csv')
# Out:
#           13.1.3    13.1.2     8.8.2  ...    16.3.2     2.5.2    15.2.1
# 13.1.3  1.000000 -0.676106  0.472808  ... -0.442466 -0.562405  0.099159
# 13.1.2 -0.676106  1.000000 -0.627903  ...  0.645497  0.697852 -0.533102
# 8.8.2   0.472808 -0.627903  1.000000  ... -0.972743 -0.873059  0.783163
# 17.9.1  0.033008 -0.161271 -0.013241  ...  0.169370  0.022344 -0.298090
# 13.1.1 -0.115534 -0.008633 -0.411302  ...  0.500472  0.619329 -0.518697
# ...          ...       ...       ...  ...       ...       ...       ...
# 1.4.1   0.444626 -0.661485  0.957657  ... -0.996532 -0.917321  0.904422
# 3.3.2  -0.454600  0.658371 -0.972272  ...  0.999516  0.912491 -0.882509
# 16.3.2 -0.442466  0.645497 -0.972743  ...  1.000000  0.917921 -0.885994
# 2.5.2  -0.562405  0.697852 -0.873059  ...  0.917921  1.000000 -0.800107
# 15.2.1  0.099159 -0.533102  0.783163  ... -0.885994 -0.800107  1.000000
#
# [94 rows x 94 columns]
