# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fexperimentsandconfigs%20https%3a%2f%2fwww.googleapis.com%2fauth%2fphotos.native&response_type=code
#
# Enter your authorization code:
# 4/1AX4XfWgoMcHbADL0RT4aIfegonlnv05YQTq_XQz4QH6HaR9ze6oGUyeEmv8
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
Indonesia=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Practicum SDG Networks/Data/indo_pc1s.csv')
Indonesia=Indonesia.rename(columns={'Unnamed: 0': 'Year'})
Indonesia=Indonesia.set_index('Year')
Indonesia_scaled=sc.fit_transform(Indonesia)
Indonesia_scaled=pd.DataFrame(Indonesia_scaled, columns=Indonesia.columns)
Indonesia
# Out:
#         13.1.3  13.1.2     8.8.2  ...        16.3.2     2.5.2    15.2.1
# Year                              ...
# 2012  1.038600    -0.5  1.506967  ... -1.549193e+00 -2.160033  2.208392
# 2013  0.325498    -0.5  1.130225  ... -1.161895e+00 -0.819323  1.656294
# 2014  0.484697    -0.5  0.753483  ... -7.745967e-01 -0.484145  1.104196
# 2015  0.242348    -0.5  0.757765  ... -3.872983e-01 -1.154500 -0.009687
# 2016 -1.528274    -0.5 -0.509458  ... -3.551675e-14 -0.484145  1.767445
# 2017  2.749971    -0.5 -0.500895  ...  3.872983e-01 -0.484145 -1.565143
# 2018  0.040330    -0.5 -0.500895  ...  7.745967e-01  1.526920 -1.700510
# 2019 -2.383776     2.5 -1.130225  ...  1.161895e+00  1.862097 -1.685386
# 2020 -0.969394     1.0 -1.506967  ...  1.549193e+00  2.197275 -1.775600
#
# [9 rows x 94 columns]

# %%
Indonesia_scaled
# Out:
#      13.1.3  13.1.2     8.8.2  ...        16.3.2     2.5.2    15.2.1
# 0  0.734401    -0.5  1.506967  ... -1.549193e+00 -1.527374  1.372575
# 1  0.230162    -0.5  1.130225  ... -1.161895e+00 -0.579349  1.029432
# 2  0.342732    -0.5  0.753483  ... -7.745967e-01 -0.342342  0.686288
# 3  0.171366    -0.5  0.757765  ... -3.872983e-01 -0.816355 -0.006020
# 4 -1.080653    -0.5 -0.509458  ... -3.544273e-14 -0.342342  1.098515
# 5  1.944523    -0.5 -0.500895  ...  3.872983e-01 -0.342342 -0.972779
# 6  0.028518    -0.5 -0.500895  ...  7.745967e-01  1.079695 -1.056913
# 7 -1.685584     2.5 -1.130225  ...  1.161895e+00  1.316702 -1.047513
# 8 -0.685465     1.0 -1.506967  ...  1.549193e+00  1.553708 -1.103584
#
# [9 rows x 94 columns]

# %%
Indonesiacorrelation=Indonesia.corr()
Indonesiascaledcorrelation=Indonesia_scaled.corr()
print(Indonesiacorrelation)
print(Indonesiascaledcorrelation)
Indonesiacorrelation.to_csv('/content/drive/MyDrive/Colab Notebooks/Practicum SDG Networks/Data/Indonesia_correlation_among_indicators_indicator_model.csv')
Indonesiascaledcorrelation.to_csv('/content/drive/MyDrive/Colab Notebooks/Practicum SDG Networks/Data/Indonesia_scaled_correlation_among_indicators_indicator_model.csv')
# Out:
#           13.1.3    13.1.2     8.8.2  ...    16.3.2     2.5.2    15.2.1
# 13.1.3  1.000000 -0.676106  0.472808  ... -0.442466 -0.562405  0.099159
# 13.1.2 -0.676106  1.000000 -0.627903  ...  0.645497  0.697852 -0.533102
# 8.8.2   0.472808 -0.627903  1.000000  ... -0.972743 -0.873059  0.783163
# 17.9.1  0.033008 -0.161271 -0.013241  ...  0.169370  0.022344 -0.298090
# 13.1.1 -0.115534 -0.008633 -0.411302  ...  0.500472  0.619329 -0.518697
# ...          ...       ...       ...  ...       ...       ...       ...
# 1.4.1   0.444626 -0.661485  0.957657  ... -0.996532 -0.917321  0.904422
# 3.3.2  -0.454600  0.658371 -0.972272  ...  0.999516  0.912491 -0.882509
# 16.3.2 -0.442466  0.645497 -0.972743  ...  1.000000  0.917921 -0.885994
# 2.5.2  -0.562405  0.697852 -0.873059  ...  0.917921  1.000000 -0.800107
# 15.2.1  0.099159 -0.533102  0.783163  ... -0.885994 -0.800107  1.000000
#
# [94 rows x 94 columns]
#           13.1.3    13.1.2     8.8.2  ...    16.3.2     2.5.2    15.2.1
# ...

# %%
Guatemala=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Practicum SDG Networks/Data/gua_pc1s.csv')
Guatemala=Guatemala.rename(columns={'Unnamed: 0': 'Year'})
Guatemala=Guatemala.set_index('Year')
Guatemala_scaled=sc.fit_transform(Guatemala)
Guatemala_scaled=pd.DataFrame(Guatemala_scaled, columns=Guatemala.columns)
Guatemala
# Out:
#         13.1.3    13.1.2     8.8.2  ...  2.5.2     3.3.1    15.2.1
# Year                                ...
# 2012 -1.694458 -1.129982 -1.528235  ...    0.0  1.814755 -2.072487
# 2013 -1.694458 -1.129982 -1.146176  ...    0.0  1.272266 -1.554366
# 2014 -1.694458 -1.129982 -0.764118  ...    0.0  0.187288 -1.036244
# 2015 -0.445283 -0.450631 -0.371591  ...    0.0  0.187288 -0.301252
# 2016  0.766447  0.077754 -0.214581  ...    0.0  0.187288  0.257694
# 2017 -0.587835  1.285490  0.779819  ...    0.0 -0.355201 -0.431855
# 2018  0.638148  1.587423  0.570471  ...    0.0 -0.897690  1.340799
# 2019  1.707325  0.887640  1.146176  ...    0.0 -0.897690  1.680061
# 2020  3.004572  0.002270  1.528235  ...    0.0 -1.498303  2.117650
#
# [9 rows x 92 columns]

# %%
Guatemala_scaled
# Out:
#      13.1.3    13.1.2     8.8.2  ...  2.5.2     3.3.1    15.2.1
# 0 -1.081459 -1.129982 -1.528235  ...    0.0  1.814755 -1.497705
# 1 -1.081459 -1.129982 -1.146176  ...    0.0  1.272266 -1.123279
# 2 -1.081459 -1.129982 -0.764118  ...    0.0  0.187288 -0.748853
# 3 -0.284194 -0.450631 -0.371591  ...    0.0  0.187288 -0.217703
# 4  0.489172  0.077754 -0.214581  ...    0.0  0.187288  0.186226
# 5 -0.375176  1.285490  0.779819  ...    0.0 -0.355201 -0.312085
# 6  0.407287  1.587423  0.570471  ...    0.0 -0.897690  0.968943
# 7  1.089672  0.887640  1.146176  ...    0.0 -0.897690  1.214114
# 8  1.917618  0.002270  1.528235  ...    0.0 -1.498303  1.530342
#
# [9 rows x 92 columns]

# %%
Guatemalacorrelation=Guatemala.corr()
Guatemalascaledcorrelation=Guatemala_scaled.corr()
print(Guatemalacorrelation)
print(Guatemalascaledcorrelation)
Guatemalacorrelation.to_csv('/content/drive/MyDrive/Colab Notebooks/Practicum SDG Networks/Data/Guatemala_correlation_among_indicators_indicator_model.csv')
Guatemalascaledcorrelation.to_csv('/content/drive/MyDrive/Colab Notebooks/Practicum SDG Networks/Data/Guatemala_scaled_correlation_among_indicators_indicator_model.csv')
# Out:
#           13.1.3    13.1.2     8.8.2  ...  2.5.2     3.3.1    15.2.1
# 13.1.3  1.000000  0.552004  0.870952  ...    NaN -0.842928  0.951848
# 13.1.2  0.552004  1.000000  0.773904  ...    NaN -0.716844  0.682061
# 8.8.2   0.870952  0.773904  1.000000  ...    NaN -0.954697  0.914352
# 17.9.1 -0.104817  0.207841 -0.123285  ...    NaN  0.085528 -0.021316
# 13.1.1  0.721152  0.095110  0.604616  ...    NaN -0.601204  0.605742
# ...          ...       ...       ...  ...    ...       ...       ...
# 3.3.2  -0.496820 -0.356398 -0.548433  ...    NaN  0.632005 -0.514143
# 16.3.2  0.920746  0.763959  0.986471  ...    NaN -0.967150  0.966765
# 2.5.2        NaN       NaN       NaN  ...    NaN       NaN       NaN
# 3.3.1  -0.842928 -0.716844 -0.954697  ...    NaN  1.000000 -0.937222
# 15.2.1  0.951848  0.682061  0.914352  ...    NaN -0.937222  1.000000
#
# [92 rows x 92 columns]
#           13.1.3    13.1.2     8.8.2  ...  2.5.2     3.3.1    15.2.1
# ...
