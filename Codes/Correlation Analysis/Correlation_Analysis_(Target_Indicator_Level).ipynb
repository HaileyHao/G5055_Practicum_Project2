# %% [markdown]
# # Correlation Analysis at Target-Indicator Level

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Import libraries and read in data

# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Read in data
Indonesia=pd.read_csv('https://github.com/PeishanLi/G5055_Practicum_Project2/raw/main/Data/processedIndo.csv')
Guatemala=pd.read_csv('https://github.com/PeishanLi/G5055_Practicum_Project2/raw/main/Data/processedGuate.csv')
Imeasures=pd.read_csv('https://github.com/PeishanLi/G5055_Practicum_Project2/raw/main/Data/measure_picked/Indo_measureIDs.csv')
Gmeasures=pd.read_csv('https://github.com/PeishanLi/G5055_Practicum_Project2/raw/main/Data/measure_picked/Gua_measureIDs.csv')

#A little preprocessing of data
Indonesia=Indonesia.drop('Unnamed: 0', axis=1)
Indonesia['UniqueIDNew']=[x.replace(" ","") for x in Indonesia['UniqueID']]
Guatemala=Guatemala.drop('Unnamed: 0', axis=1)
Guatemala['UniqueIDNew']=[x.replace(" ","") for x in Guatemala['UniqueID']]
Imeasures['xNew']=[x.replace(" ","") for x in Imeasures['x']]
Gmeasures['xNew']=[x.replace(" ","") for x in Gmeasures['x']]

# %%
Indonesia['UniqueIDNew'].head(20)
# Out:
# 0                 SI_POV_DAY1
# 1                 SI_POV_DAY1
# 2                 SI_POV_DAY1
# 3                 SI_POV_DAY1
# 4                 SI_POV_DAY1
# 5                 SI_POV_DAY1
# 6                 SI_POV_DAY1
# 7                 SI_POV_DAY1
# 8      SI_POV_EMP1FEMALE15-24
# 9        SI_POV_EMP1FEMALE15+
# 10       SI_POV_EMP1FEMALE25+
# 11       SI_POV_EMP1MALE15-24
# 12      SI_POV_EMP1BOTHSEX15+
# 13    SI_POV_EMP1BOTHSEX15-24
# 14      SI_POV_EMP1BOTHSEX25+
# 15         SI_POV_EMP1MALE25+
# 16         SI_POV_EMP1MALE15+
# 17       SI_POV_EMP1FEMALE15+
# 18       SI_POV_EMP1FEMALE25+
# 19      SI_POV_EMP1BOTHSEX15+
# Name: UniqueIDNew, dtype: object

# %%
Imeasures
# Out:
#                                            x                   xNew
# 0    SI_POV_EMP1 BOTHSEX                 15+  SI_POV_EMP1BOTHSEX15+
# 1               SI_POV_NAHC          ALLAREA     SI_POV_NAHCALLAREA
# 2     SI_COV_SOCAST                       Q1        SI_COV_SOCASTQ1
# 3              SP_ACS_BSRVH2O          RURAL    SP_ACS_BSRVH2ORURAL
# 4                      SP_LGL_LNDDOC BOTHSEX   SP_LGL_LNDDOCBOTHSEX
# ..                                       ...                    ...
# 234                              BX_TRF_PWKR            BX_TRF_PWKR
# 235                               GF_FRN_FDI             GF_FRN_FDI
# 236                              DT_TDS_DECT            DT_TDS_DECT
# 237                              IT_USE_ii99            IT_USE_ii99
# 238                             DC_FTA_TOTAL           DC_FTA_TOTAL
#
# [239 rows x 2 columns]

# %% [markdown]
# ## Filter data
#
# Measure the measures picked using Rmd file with the original dataset, to identify which indicator of which target and goal it belongs to, and filters the original dataset for further correlation analysis at target-indicator level.

# %% [markdown]
# Method 1

# %%
FilteredIndo=pd.DataFrame()
FilteredGuate=pd.DataFrame()

# %%
def filter_data(df, filtered):
  for i in range(len(df)):
    if df['UniqueIDNew'][i] in Imeasures['xNew']:
      filtered=filtered.append(df.loc[i])
  #filtered.to_csv('/content/drive/MyDrive/Colab Notebooks/Practicum SDG Networks/Data/Indonesia data after selecting one measurement for each indicator.csv')
  #print('Filtering completed!')
  return filtered

# %%
filter_data(Indonesia, FilteredIndo)
# Out:
#                                             UniqueID  ...            UniqueIDNew
# 12    SI_POV_EMP1 BOTHSEX                 15+         ...  SI_POV_EMP1BOTHSEX15+
# 19    SI_POV_EMP1 BOTHSEX                 15+         ...  SI_POV_EMP1BOTHSEX15+
# 28    SI_POV_EMP1 BOTHSEX                 15+         ...  SI_POV_EMP1BOTHSEX15+
# 43    SI_POV_EMP1 BOTHSEX                 15+         ...  SI_POV_EMP1BOTHSEX15+
# 48    SI_POV_EMP1 BOTHSEX                 15+         ...  SI_POV_EMP1BOTHSEX15+
# ...                                              ...  ...                    ...
# 4225           DC_FTA_TOTAL                           ...           DC_FTA_TOTAL
# 4226           DC_FTA_TOTAL                           ...           DC_FTA_TOTAL
# 4227           DC_FTA_TOTAL                           ...           DC_FTA_TOTAL
# 4228           DC_FTA_TOTAL                           ...           DC_FTA_TOTAL
# 4229           DC_FTA_TOTAL                           ...           DC_FTA_TOTAL
#
# [874 rows x 8 columns]

# %% [markdown]
# Method 2

# %%
FilteredIndo=Indonesia.copy()
is_included=FilteredIndo['UniqueIDNew'].isin(Imeasures['xNew'])
FilteredIndo=FilteredIndo[is_included]
FilteredIndo.to_csv('/content/drive/MyDrive/Colab Notebooks/Practicum SDG Networks/Data/Indonesia data after selecting one measurement for each indicator.csv')
FilteredIndo
# Out:
#                                             UniqueID  ...            UniqueIDNew
# 12    SI_POV_EMP1 BOTHSEX                 15+         ...  SI_POV_EMP1BOTHSEX15+
# 19    SI_POV_EMP1 BOTHSEX                 15+         ...  SI_POV_EMP1BOTHSEX15+
# 28    SI_POV_EMP1 BOTHSEX                 15+         ...  SI_POV_EMP1BOTHSEX15+
# 43    SI_POV_EMP1 BOTHSEX                 15+         ...  SI_POV_EMP1BOTHSEX15+
# 48    SI_POV_EMP1 BOTHSEX                 15+         ...  SI_POV_EMP1BOTHSEX15+
# ...                                              ...  ...                    ...
# 4225           DC_FTA_TOTAL                           ...           DC_FTA_TOTAL
# 4226           DC_FTA_TOTAL                           ...           DC_FTA_TOTAL
# 4227           DC_FTA_TOTAL                           ...           DC_FTA_TOTAL
# 4228           DC_FTA_TOTAL                           ...           DC_FTA_TOTAL
# 4229           DC_FTA_TOTAL                           ...           DC_FTA_TOTAL
#
# [874 rows x 8 columns]

# %%
FilteredGuate=Guatemala.copy()
is_included=FilteredGuate['UniqueIDNew'].isin(Gmeasures['xNew'])
FilteredGuate=FilteredGuate[is_included]
FilteredGuate.to_csv('/content/drive/MyDrive/Colab Notebooks/Practicum SDG Networks/Data/Guatemala data after selecting one measurement for each indicator.csv')
FilteredGuate
# Out:
#                                             UniqueID  ...            UniqueIDNew
# 4     SI_POV_EMP1 BOTHSEX                 15+         ...  SI_POV_EMP1BOTHSEX15+
# 10    SI_POV_EMP1 BOTHSEX                 15+         ...  SI_POV_EMP1BOTHSEX15+
# 25    SI_POV_EMP1 BOTHSEX                 15+         ...  SI_POV_EMP1BOTHSEX15+
# 28    SI_POV_EMP1 BOTHSEX                 15+         ...  SI_POV_EMP1BOTHSEX15+
# 38    SI_POV_EMP1 BOTHSEX                 15+         ...  SI_POV_EMP1BOTHSEX15+
# ...                                              ...  ...                    ...
# 4780           DC_FTA_TOTAL                           ...           DC_FTA_TOTAL
# 4781           DC_FTA_TOTAL                           ...           DC_FTA_TOTAL
# 4782           DC_FTA_TOTAL                           ...           DC_FTA_TOTAL
# 4783           DC_FTA_TOTAL                           ...           DC_FTA_TOTAL
# 4784           DC_FTA_TOTAL                           ...           DC_FTA_TOTAL
#
# [826 rows x 8 columns]

# %% [markdown]
# ## Preprocess data into desired format

# %% [markdown]
# ## Calculate correlation among indicators

# %%
def calculate_correlation(df):
  Alltargets=df['Target'].drop_duplicates()
  for target in Alltargets:
    Allindicators=list(df['Indicator'].drop_duplicates())
    if len(Allindicators)>1:
      group=df[df['Target']==target]
      group=group.drop(columns=['UniqueID','Goal','Target','SeriesCode','UniqueIDNew'],axis=1)
      group_pivot=group.pivot(index=['TimePeriod'], columns=['Indicator'], values='Value').reset_index()
      group_pivot=group_pivot.apply(lambda x:x.astype(float))
      correlation=group_pivot.corr()
      correlation=pd.DataFrame(correlation)
      correlation=correlation.drop('TimePeriod', axis=1)
      correlation=correlation.drop('TimePeriod', axis=0)
      path='/content/drive/MyDrive/Colab Notebooks/Practicum SDG Networks/Data/Indonesia Correlation among Indicators/Indonesia Correlation among Indicators of Target '+target+'.csv'
      correlation.to_csv(path)
      print('Target '+target+' completed')

# %%
calculate_correlation(FilteredIndo)
# Out:
# Target 1.1 completed
# Target 1.2 completed
# Target 1.3 completed
# Target 1.4 completed
# Target 1.5 completed
# Target 1.a completed
# Target 2.1 completed
# Target 2.2 completed
# Target 2.3 completed
# Target 2.5 completed
# Target 2.a completed
# Target 2.b completed
# Target 2.c completed
# Target 3.1 completed
# Target 3.2 completed
# Target 3.3 completed
# Target 3.4 completed
# Target 3.5 completed
# Target 3.6 completed
# Target 3.7 completed
# Target 3.8 completed
# Target 3.9 completed
# Target 3.a completed
# Target 3.b completed
# Target 3.c completed
# Target 3.d completed
# Target 4.1 completed
# Target 4.2 completed
# Target 4.3 completed
# Target 4.4 completed
# Target 4.5 completed
# Target 4.7 completed
# Target 4.a completed
# Target 4.b completed
# Target 5.2 completed
# Target 5.3 completed
# Target 5.5 completed
# Target 5.a completed
# Target 5.b completed
# Target 6.2 completed
# Target 6.4 completed
# Target 6.5 completed
# Target 6.6 completed
# Target 6.a completed
# Target 6.b completed
# Target 7.1 completed
# Target 7.2 completed
# Target 7.3 completed
# Target 7.a completed
# Target 7.b completed
# Target 8.1 completed
# Target 8.10 completed
# Target 8.2 completed
# Target 8.3 completed
# Target 8.4 completed
# Target 8.5 completed
# Target 8.6 completed
# Target 8.8 completed
# Target 8.9 completed
# Target 8.a completed
# Target 8.b completed
# Target 9.1 completed
# Target 9.2 completed
# Target 9.3 completed
# Target 9.4 completed
# Target 9.5 completed
# Target 9.a completed
# Target 9.b completed
# Target 9.c completed
# Target 10.1 completed
# Target 10.4 completed
# Target 10.5 completed
# Target 10.6 completed
# Target 10.7 completed
# Target 10.a completed
# Target 10.b completed
# Target 10.c completed
# Target 11.1 completed
# Target 11.5 completed
# Target 11.6 completed
# Target 11.a completed
# Target 11.b completed
# Target 12.1 completed
# Target 12.2 completed
# Target 12.3 completed
# Target 12.4 completed
# Target 12.6 completed
# Target 12.8 completed
# Target 12.a completed
# Target 12.b completed
# Target 12.c completed
# Target 13.1 completed
# Target 13.3 completed
# Target 14.1 completed
# Target 14.4 completed
# Target 14.5 completed
# Target 14.6 completed
# Target 14.7 completed
# Target 14.b completed
# Target 15.1 completed
# Target 15.2 completed
# Target 15.3 completed
# Target 15.4 completed
# Target 15.5 completed
# Target 15.6 completed
# Target 15.8 completed
# Target 15.9 completed
# Target 15.a completed
# Target 15.b completed
# Target 16.1 completed
# Target 16.10 completed
# Target 16.2 completed
# Target 16.3 completed
# Target 16.5 completed
# Target 16.6 completed
# Target 16.7 completed
# Target 16.8 completed
# Target 16.9 completed
# Target 16.a completed
# Target 17.1 completed
# Target 17.10 completed
# Target 17.12 completed
# Target 17.13 completed
# Target 17.17 completed
# Target 17.18 completed
# Target 17.19 completed
# Target 17.3 completed
# Target 17.4 completed
# Target 17.6 completed
# Target 17.8 completed
# Target 17.9 completed

# %%
def calculate_correlation(df):
  Alltargets=df['Target'].drop_duplicates()
  for target in Alltargets:
    Allindicators=list(df['Indicator'].drop_duplicates())
    if len(Allindicators)>1:
      group=df[df['Target']==target]
      group=group.drop(columns=['UniqueID','Goal','Target','SeriesCode','UniqueIDNew'],axis=1)
      group_pivot=group.pivot(index=['TimePeriod'], columns=['Indicator'], values='Value').reset_index()
      group_pivot=group_pivot.apply(lambda x:x.astype(float))
      correlation=group_pivot.corr()
      correlation=pd.DataFrame(correlation)
      correlation=correlation.drop('TimePeriod', axis=1)
      correlation=correlation.drop('TimePeriod', axis=0)
      path='/content/drive/MyDrive/Colab Notebooks/Practicum SDG Networks/Data/Guatemala Correlation among Indicators/Guatemala Correlation among Indicators of Target '+target+'.csv'
      correlation.to_csv(path)
      print('Target '+target+' completed')

# %%
calculate_correlation(FilteredGuate)
# Out:
# Target 1.1 completed
# Target 1.2 completed
# Target 1.3 completed
# Target 1.4 completed
# Target 1.5 completed
# Target 1.a completed
# Target 2.1 completed
# Target 2.2 completed
# Target 2.3 completed
# Target 2.5 completed
# Target 2.a completed
# Target 2.c completed
# Target 3.1 completed
# Target 3.2 completed
# Target 3.3 completed
# Target 3.4 completed
# Target 3.5 completed
# Target 3.6 completed
# Target 3.7 completed
# Target 3.8 completed
# Target 3.9 completed
# Target 3.b completed
# Target 3.c completed
# Target 3.d completed
# Target 4.1 completed
# Target 4.2 completed
# Target 4.3 completed
# Target 4.5 completed
# Target 4.7 completed
# Target 4.b completed
# Target 5.2 completed
# Target 5.3 completed
# Target 5.5 completed
# Target 5.a completed
# Target 6.2 completed
# Target 6.4 completed
# Target 6.5 completed
# Target 6.6 completed
# Target 6.a completed
# Target 6.b completed
# Target 7.1 completed
# Target 7.2 completed
# Target 7.3 completed
# Target 7.a completed
# Target 7.b completed
# Target 8.1 completed
# Target 8.10 completed
# Target 8.2 completed
# Target 8.3 completed
# Target 8.4 completed
# Target 8.5 completed
# Target 8.6 completed
# Target 8.8 completed
# Target 8.a completed
# Target 8.b completed
# Target 9.1 completed
# Target 9.2 completed
# Target 9.3 completed
# Target 9.4 completed
# Target 9.5 completed
# Target 9.a completed
# Target 9.b completed
# Target 9.c completed
# Target 10.4 completed
# Target 10.5 completed
# Target 10.6 completed
# Target 10.7 completed
# Target 10.a completed
# Target 10.b completed
# Target 10.c completed
# Target 11.1 completed
# Target 11.5 completed
# Target 11.6 completed
# Target 11.a completed
# Target 11.b completed
# Target 12.1 completed
# Target 12.2 completed
# Target 12.3 completed
# Target 12.4 completed
# Target 12.6 completed
# Target 12.8 completed
# Target 12.a completed
# Target 12.b completed
# Target 12.c completed
# Target 13.1 completed
# Target 13.3 completed
# Target 14.1 completed
# Target 14.4 completed
# Target 14.5 completed
# Target 14.6 completed
# Target 14.7 completed
# Target 14.b completed
# Target 15.1 completed
# Target 15.2 completed
# Target 15.3 completed
# Target 15.4 completed
# Target 15.5 completed
# Target 15.6 completed
# Target 15.8 completed
# Target 15.a completed
# Target 15.b completed
# Target 16.10 completed
# Target 16.2 completed
# Target 16.3 completed
# Target 16.5 completed
# Target 16.6 completed
# Target 16.8 completed
# Target 16.9 completed
# Target 16.a completed
# Target 17.1 completed
# Target 17.10 completed
# Target 17.12 completed
# Target 17.13 completed
# Target 17.17 completed
# Target 17.18 completed
# Target 17.19 completed
# Target 17.3 completed
# Target 17.4 completed
# Target 17.6 completed
# Target 17.8 completed
# Target 17.9 completed
