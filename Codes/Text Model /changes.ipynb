# %%
import pandas as pd
import os
import re

# %%
# list all the pdfs
pdf_path = os.listdir('SDG-indicator-pdfs')

#add in directory
pdf_path = ['SDG-indicator-pdfs/' + path for path in pdf_path]

# there's one called .ds-store, dont know why, so i deleted it'
#pdf_path.remove('SDG-indicator-pdfs/.DS_Store')

# %%
len(pdf_path)
# Out:
# 246

# %%
#install package
#pip install PyMuPDF

# %%
import fitz

def get_text(filepath: str) -> str:
    with fitz.open(filepath) as doc:
        text = ""
        for page in doc:
            text += page.getText()
        return text
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-03fc50bf9000> in <module>
# ----> 1 import fitz
#       2
#       3 def get_text(filepath: str) -> str:
#       4     with fitz.open(filepath) as doc:
#       5         text = ""
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fitz/__init__.py in <module>
# ----> 1 from frontend import *
#       2 import tools
#       3 import os.path as op
#       4
#       5 __version__ = '0.0.1dev2'
#
# ModuleNotFoundError: No module named 'frontend'

# %%
import pandas as pd 
lst1 = pdf_path
lst2 = [get_text(path) for path in pdf_path]

percentile_list = pd.DataFrame(
    {'pdf_name': lst1,
     'pdf_text': lst2
    })
percentile_list = percentile_list.sort_values('pdf_name')
percentile_list.to_csv('text_chunk.csv')

# %%
text_chunk = pd.read_csv('text_chunk.csv')
text_chunk
# Out:
#      Unnamed: 0                                   pdf_name  \
# 0           217  SDG-indicator-pdfs/Metadata-01-01-01a.pdf
# 1           193   SDG-indicator-pdfs/Metadata-01-02-01.pdf
# 2           205   SDG-indicator-pdfs/Metadata-01-02-02.pdf
# 3           114  SDG-indicator-pdfs/Metadata-01-03-01a.pdf
# 4           140   SDG-indicator-pdfs/Metadata-01-04-01.pdf
# ..          ...                                        ...
# 241         115   SDG-indicator-pdfs/Metadata-17-17-01.pdf
# 242          55   SDG-indicator-pdfs/Metadata-17-18-02.pdf
# 243          50   SDG-indicator-pdfs/Metadata-17-18-03.pdf
# 244         165   SDG-indicator-pdfs/Metadata-17-19-01.pdf
# 245          74  SDG-indicator-pdfs/Metadata-17-19-02a.pdf
#
#                                               pdf_text
# 0    Last updated: July 2021 \nSDG indicator metada...
# 1    Last updated: August 2021 \nSDG indicator meta...
# 2    Last updated: May 2021 \nSDG indicator metadat...
# 3    Last updated: January 2021 \nSDG indicator met...
# 4    Last updated: March 2021 \nSDG indicator metad...
# ..                                                 ...
# 241  Last updated: September 2020 \nGoal 17: Streng...
# 242  Last updated: 13 February 2018 \n \nGoal 17: S...
# 243  Last updated: 11 July 2017 \n \nGoal 17: Stren...
# 244  Last updated: 11 July 2017 \n \nGoal 17: Stren...
# 245  Last updated: 19 July 2016 \n \nGoal 17: Stren...
#
# [246 rows x 3 columns]

# %%
# find the definition from .pdf files

definition_all = {}
d_pattern = 'Definition:'
c_pattern = 'Concepts:'
error = []
for i in range(text_chunk.shape[0]):
    try:
        test_str = text_chunk.iloc[i]['pdf_text']
        definition_index = [(m.start(0), m.end(0)) for m in re.finditer(d_pattern, test_str)]
        concept_goal = [(m.start(0), m.end(0)) for m in re.finditer(c_pattern, test_str)]
        definition = test_str[definition_index[0][1]+2:concept_goal[0][0]]
        definition_all[text_chunk.iloc[i]['pdf_name']] = definition
    except:
        error.append(text_chunk.iloc[i]['pdf_name'])
        #print(text_chunk.iloc[i]['pdf_name'])
        definition_all[text_chunk.iloc[i]['pdf_name']] = ''

text_chunk['definition']= text_chunk['pdf_name'].map(definition_all)
df = pd.DataFrame(definition_all.items())

# %%
#keep XX-XX-XXa eg 01-01-01
df['Index'] = df[0].apply(lambda x: x.replace('SDG-indicator-pdfs/Metadata-',"").replace('.pdf',''))
df = df.rename(columns={0:'pdf_name',1:'definition' })

# %%
#change 01 02 to 1 2 eg 01-01-01 to 1-01-01
df['Index'] = df['Index'].apply(lambda x: x[1:] if x[0] == '0' else x)
#lowercase the string
df['Index'] = df["Index"]. str. lower() 
#replace -0 with .
df['Index'] = df['Index'].apply(lambda x: x.replace('-0',".").replace('-','.'))
#get rid of the end 'a' eg 1.1.1a to 1.1.1
df['Index'] = df['Index'].apply(lambda x: x.replace('a','') if x[-1] == 'a' else x)

# %%
goal_target_indicator = pd.read_excel('Goal_Target_Indicator.xlsx')
# two NaN in subset 
goal_target_indicator = goal_target_indicator.dropna(subset = ['Index'])
len(goal_target_indicator['Index'])
# Out:
# 247

# %%
goal_target_indicator['Index']
# Out:
# 0        1.1.1
# 1        1.2.1
# 2        1.2.2
# 3        1.3.1
# 4        1.4.1
# 5        1.4.2
# 6        1.5.1
# 7        1.5.2
# 8        1.5.3
# 9        1.5.4
# 10       1.a.1
# 11       1.a.2
# 12       1.b.1
# 13       2.1.1
# 14       2.1.2
# 15       2.2.1
# 16       2.2.2
# 17       2.2.3
# 18       2.3.1
# 19       2.3.2
# 20       2.4.1
# 21       2.5.1
# 22       2.5.2
# 23       2.a.1
# 24       2.a.2
# 25       2.b.1
# 26       2.c.1
# 27       3.1.1
# 28       3.1.2
# 29       3.2.1
# 30       3.2.2
# 31       3.3.1
# 32       3.3.2
# 33       3.3.3
# 34       3.3.4
# 35       3.3.5
# 36       3.4.1
# 37       3.4.2
# 38       3.5.1
# 39       3.5.2
# 40       3.6.1
# 41       3.7.1
# 42       3.7.2
# 43       3.8.1
# 44       3.8.2
# 45       3.9.1
# 46       3.9.2
# 47       3.9.3
# 48       3.a.1
# 49       3.b.1
# 50       3.b.2
# 51       3.b.3
# 52       3.c.1
# 53       3.d.1
# 54       3.d.2
# 55       4.1.1
# 56       4.1.2
# 57       4.2.1
# 58       4.2.2
# 59       4.3.1
# 60       4.4.1
# 61       4.5.1
# 62       4.6.1
# 63       4.7.1
# 64       4.a.1
# 65       4.b.1
# 66       4.c.1
# 67       5.1.1
# 68       5.2.1
# 69       5.2.2
# 70       5.3.1
# 71       5.3.2
# 72       5.4.1
# 73       5.5.1
# 74       5.5.2
# 75       5.6.1
# 76       5.6.2
# 77       5.a.1
# 78       5.a.2
# 79       5.b.1
# 80       5.c.1
# 81       6.1.1
# 82       6.2.1
# 83       6.3.1
# 84       6.3.2
# 85       6.4.1
# 86       6.4.2
# 87       6.5.1
# 88       6.5.2
# 89       6.6.1
# 90       6.a.1
# 91       6.b.1
# 92       7.1.1
# 93       7.1.2
# 94       7.2.1
# 95       7.3.1
# 96       7.a.1
# 97       7.b.1
# 98       8.1.1
# 99       8.2.1
# 100      8.3.1
# 101      8.4.1
# 102      8.4.2
# 103      8.5.1
# 104      8.5.2
# 105      8.6.1
# 106      8.7.1
# 107      8.8.1
# 108      8.8.2
# 109      8.9.1
# 110      8.10.
# 111      8.10.
# 112      8.a.1
# 113      8.b.1
# 114      9.1.1
# 115      9.1.2
# 116      9.2.1
# 117      9.2.2
# 118      9.3.1
# 119      9.3.2
# 120      9.4.1
# 121      9.5.1
# 122      9.5.2
# 123      9.a.1
# 124      9.b.1
# 125      9.c.1
# 126     10.1.1
# 127     10.2.1
# 128     10.3.1
# 129     10.4.1
# 130     10.4.2
# 131     10.5.1
# 132     10.6.1
# 133     10.7.1
# 134     10.7.2
# 135     10.7.3
# 136     10.7.4
# 137     10.a.1
# 138     10.b.1
# 139     10.c.1
# 140     11.1.1
# 141     11.2.1
# 142     11.3.1
# 143     11.3.2
# 144     11.4.1
# 145     11.5.1
# 146     11.5.2
# 147     11.6.1
# 148     11.6.2
# 149     11.7.1
# 150     11.7.2
# 151     11.a.1
# 152     11.b.1
# 153     11.b.2
# 155     12.1.1
# 156     12.2.1
# 157     12.2.2
# 158     12.3.1
# 159     12.4.1
# 160     12.4.2
# 161     12.5.1
# 162     12.6.1
# 163     12.7.1
# 164     12.8.1
# 165     12.a.1
# 166     12.b.1
# 167     12.c.1
# 168     13.1.1
# 169     13.1.2
# 170     13.1.3
# 171     13.2.1
# 172     13.2.2
# 173     13.3.1
# 174     13.a.1
# 175     13.b.1
# 176     14.1.1
# 177     14.2.1
# 178     14.3.1
# 179     14.4.1
# 180     14.5.1
# 181     14.6.1
# 182     14.7.1
# 183     14.a.1
# 184     14.b.1
# 185     14.c.1
# 186     15.1.1
# 187     15.1.2
# 188     15.2.1
# 189     15.3.1
# 190     15.4.1
# 191     15.4.2
# 192     15.5.1
# 193     15.6.1
# 194     15.7.1
# 195     15.8.1
# 196     15.9.1
# 197     15.a.1
# 198     15.b.1
# 199     15.c.1
# 200     16.1.1
# 201     16.1.2
# 202     16.1.3
# 203     16.1.4
# 204     16.2.1
# 205     16.2.2
# 206     16.2.3
# 207     16.3.1
# 208     16.3.2
# 209     16.3.3
# 210     16.4.1
# 211     16.4.2
# 212     16.5.1
# 213     16.5.2
# 214     16.6.1
# 215     16.6.2
# 216     16.7.1
# 217     16.7.2
# 218     16.8.1
# 219     16.9.1
# 220    16.10.1
# 221    16.10.2
# 222    16.a.1
# 223    16.b.1
# 224    17.1.1
# 225    17.1.2
# 226    17.2.1
# 227    17.3.1
# 228    17.3.2
# 229    17.4.1
# 230    17.5.1
# 232    17.6.1
# 233    17.7.1
# 234    17.8.1
# 235    17.9.1
# 236    17.10.1
# 237    17.11.1
# 238    17.12.1
# 239    17.13.1
# 240    17.14.1
# 241    17.15.1
# 242    17.16.1
# 243    17.17.1
# 244    17.18.1
# 245    17.18.2
# 246    17.18.3
# 247    17.19.1
# 248    17.19.2
# Name: Index, dtype: object

# %%
B = goal_target_indicator['Index']
B
# Out:
# 0        1.1.1
# 1        1.2.1
# 2        1.2.2
# 3        1.3.1
# 4        1.4.1
# 5        1.4.2
# 6        1.5.1
# 7        1.5.2
# 8        1.5.3
# 9        1.5.4
# 10       1.a.1
# 11       1.a.2
# 12       1.b.1
# 13       2.1.1
# 14       2.1.2
# 15       2.2.1
# 16       2.2.2
# 17       2.2.3
# 18       2.3.1
# 19       2.3.2
# 20       2.4.1
# 21       2.5.1
# 22       2.5.2
# 23       2.a.1
# 24       2.a.2
# 25       2.b.1
# 26       2.c.1
# 27       3.1.1
# 28       3.1.2
# 29       3.2.1
# 30       3.2.2
# 31       3.3.1
# 32       3.3.2
# 33       3.3.3
# 34       3.3.4
# 35       3.3.5
# 36       3.4.1
# 37       3.4.2
# 38       3.5.1
# 39       3.5.2
# 40       3.6.1
# 41       3.7.1
# 42       3.7.2
# 43       3.8.1
# 44       3.8.2
# 45       3.9.1
# 46       3.9.2
# 47       3.9.3
# 48       3.a.1
# 49       3.b.1
# 50       3.b.2
# 51       3.b.3
# 52       3.c.1
# 53       3.d.1
# 54       3.d.2
# 55       4.1.1
# 56       4.1.2
# 57       4.2.1
# 58       4.2.2
# 59       4.3.1
# 60       4.4.1
# 61       4.5.1
# 62       4.6.1
# 63       4.7.1
# 64       4.a.1
# 65       4.b.1
# 66       4.c.1
# 67       5.1.1
# 68       5.2.1
# 69       5.2.2
# 70       5.3.1
# 71       5.3.2
# 72       5.4.1
# 73       5.5.1
# 74       5.5.2
# 75       5.6.1
# 76       5.6.2
# 77       5.a.1
# 78       5.a.2
# 79       5.b.1
# 80       5.c.1
# 81       6.1.1
# 82       6.2.1
# 83       6.3.1
# 84       6.3.2
# 85       6.4.1
# 86       6.4.2
# 87       6.5.1
# 88       6.5.2
# 89       6.6.1
# 90       6.a.1
# 91       6.b.1
# 92       7.1.1
# 93       7.1.2
# 94       7.2.1
# 95       7.3.1
# 96       7.a.1
# 97       7.b.1
# 98       8.1.1
# 99       8.2.1
# 100      8.3.1
# 101      8.4.1
# 102      8.4.2
# 103      8.5.1
# 104      8.5.2
# 105      8.6.1
# 106      8.7.1
# 107      8.8.1
# 108      8.8.2
# 109      8.9.1
# 110      8.10.
# 111      8.10.
# 112      8.a.1
# 113      8.b.1
# 114      9.1.1
# 115      9.1.2
# 116      9.2.1
# 117      9.2.2
# 118      9.3.1
# 119      9.3.2
# 120      9.4.1
# 121      9.5.1
# 122      9.5.2
# 123      9.a.1
# 124      9.b.1
# 125      9.c.1
# 126     10.1.1
# 127     10.2.1
# 128     10.3.1
# 129     10.4.1
# 130     10.4.2
# 131     10.5.1
# 132     10.6.1
# 133     10.7.1
# 134     10.7.2
# 135     10.7.3
# 136     10.7.4
# 137     10.a.1
# 138     10.b.1
# 139     10.c.1
# 140     11.1.1
# 141     11.2.1
# 142     11.3.1
# 143     11.3.2
# 144     11.4.1
# 145     11.5.1
# 146     11.5.2
# 147     11.6.1
# 148     11.6.2
# 149     11.7.1
# 150     11.7.2
# 151     11.a.1
# 152     11.b.1
# 153     11.b.2
# 155     12.1.1
# 156     12.2.1
# 157     12.2.2
# 158     12.3.1
# 159     12.4.1
# 160     12.4.2
# 161     12.5.1
# 162     12.6.1
# 163     12.7.1
# 164     12.8.1
# 165     12.a.1
# 166     12.b.1
# 167     12.c.1
# 168     13.1.1
# 169     13.1.2
# 170     13.1.3
# 171     13.2.1
# 172     13.2.2
# 173     13.3.1
# 174     13.a.1
# 175     13.b.1
# 176     14.1.1
# 177     14.2.1
# 178     14.3.1
# 179     14.4.1
# 180     14.5.1
# 181     14.6.1
# 182     14.7.1
# 183     14.a.1
# 184     14.b.1
# 185     14.c.1
# 186     15.1.1
# 187     15.1.2
# 188     15.2.1
# 189     15.3.1
# 190     15.4.1
# 191     15.4.2
# 192     15.5.1
# 193     15.6.1
# 194     15.7.1
# 195     15.8.1
# 196     15.9.1
# 197     15.a.1
# 198     15.b.1
# 199     15.c.1
# 200     16.1.1
# 201     16.1.2
# 202     16.1.3
# 203     16.1.4
# 204     16.2.1
# 205     16.2.2
# 206     16.2.3
# 207     16.3.1
# 208     16.3.2
# 209     16.3.3
# 210     16.4.1
# 211     16.4.2
# 212     16.5.1
# 213     16.5.2
# 214     16.6.1
# 215     16.6.2
# 216     16.7.1
# 217     16.7.2
# 218     16.8.1
# 219     16.9.1
# 220    16.10.1
# 221    16.10.2
# 222    16.a.1
# 223    16.b.1
# 224    17.1.1
# 225    17.1.2
# 226    17.2.1
# 227    17.3.1
# 228    17.3.2
# 229    17.4.1
# 230    17.5.1
# 232    17.6.1
# 233    17.7.1
# 234    17.8.1
# 235    17.9.1
# 236    17.10.1
# 237    17.11.1
# 238    17.12.1
# 239    17.13.1
# 240    17.14.1
# 241    17.15.1
# 242    17.16.1
# 243    17.17.1
# 244    17.18.1
# 245    17.18.2
# 246    17.18.3
# 247    17.19.1
# 248    17.19.2
# Name: Index, dtype: object

# %%
A = df['Index']
len(A)
# Out:
# 246

# %%
A
# Out:
# 0        1.1.1
# 1        1.2.1
# 2        1.2.2
# 3        1.3.1
# 4        1.4.1
# 5        1.4.2
# 6        1.5.1
# 7        1.5.2
# 8        1.5.3
# 9        1.5.4
# 10       1.a.1
# 11       1.a.2
# 12       1.b.1
# 13       2.1.1
# 14       2.1.2
# 15       2.2.1
# 16       2.2.2
# 17       2.2.3
# 18       2.3.1
# 19       2.3.2
# 20       2.4.1
# 21       2.5.1
# 22       2.5.2
# 23       2.a.1
# 24       2.a.2
# 25       2.b.1
# 26       2.c.1
# 27       3.1.1
# 28       3.1.2
# 29       3.2.1
# 30       3.2.2
# 31       3.3.1
# 32       3.3.2
# 33       3.3.3
# 34       3.3.4
# 35       3.3.5
# 36       3.4.1
# 37       3.4.2
# 38       3.5.1
# 39       3.5.2
# 40       3.6.1
# 41       3.7.1
# 42       3.7.2
# 43       3.8.1
# 44       3.8.2
# 45       3.9.1
# 46       3.9.2
# 47       3.9.3
# 48       3.b.2
# 49       3.b.3
# 50       3.c.1
# 51       3.a.1
# 52       3.b.1
# 53       3.d.1
# 54       3.d.2
# 55       4.1.1
# 56       4.1.2
# 57       4.2.1
# 58       4.2.2
# 59       4.3.1
# 60       4.4.1
# 61       4.5.1
# 62       4.6.1
# 63       4.7.1
# 64       4.b.1
# 65       4.c.1
# 66       4.a.1
# 67       5.1.1
# 68       5.2.1
# 69       5.2.2
# 70       5.3.1
# 71       5.3.2
# 72       5.4.1
# 73       5.5.1
# 74       5.5.2
# 75       5.6.1
# 76       5.6.2
# 77       5.a.2
# 78       5.a.1
# 79       5.b.1
# 80       5.c.1
# 81       6.1.1
# 82       6.2.1
# 83       6.3.1
# 84       6.3.2
# 85       6.4.1
# 86       6.4.2
# 87       6.5.1
# 88       6.5.2
# 89       6.6.1
# 90       6.a.1
# 91       6.b.1
# 92       7.1.1
# 93       7.1.2
# 94       7.2.1
# 95       7.3.1
# 96       7.a.1
# 97       7.b.1
# 98       8.1.1
# 99       8.2.1
# 100      8.3.1
# 101      8.4.1
# 102      8.4.2
# 103      8.5.1
# 104      8.5.2
# 105      8.6.1
# 106      8.7.1
# 107      8.8.1
# 108      8.8.2
# 109      8.9.1
# 110      8.a.1
# 111      8.b.1
# 112     8.10.1
# 113     8.10.2
# 114      9.1.1
# 115      9.1.2
# 116      9.2.1
# 117      9.2.2
# 118      9.3.1
# 119      9.3.2
# 120      9.4.1
# 121      9.5.1
# 122      9.5.2
# 123      9.a.1
# 124      9.b.1
# 125      9.c.1
# 126     10.1.1
# 127     10.2.1
# 128     10.3.1
# 129     10.4.1
# 130     10.4.2
# 131     10.5.1
# 132     10.6.1
# 133     10.7.1
# 134     10.7.2
# 135     10.7.3
# 136     10.7.4
# 137     10.a.1
# 138     10.b.1
# 139     10.c.1
# 140     11.1.1
# 141     11.2.1
# 142     11.3.1
# 143     11.3.2
# 144     11.4.1
# 145     11.5.1
# 146     11.5.2
# 147     11.6.1
# 148     11.6.2
# 149     11.7.1
# 150     11.7.2
# 151     11.b.1
# 152     11.b.2
# 153     11.a.1
# 154     12.1.1
# 155     12.2.1
# 156     12.2.2
# 157     12.3.1
# 158     12.4.1
# 159     12.4.2
# 160     12.5.1
# 161     12.6.1
# 162     12.7.1
# 163     12.8.1
# 164     12.a.1
# 165     12.b.1
# 166     12.c.1
# 167     13.1.1
# 168     13.1.2
# 169     13.1.3
# 170     13.2.1
# 171     13.2.2
# 172     13.3.1
# 173     13.a.1
# 174     13.b.1
# 175     14.1.1
# 176     14.2.1
# 177     14.3.1
# 178     14.4.1
# 179     14.5.1
# 180     14.6.1
# 181     14.7.1
# 182     14.a.1
# 183     14.b.1
# 184     14.c.1
# 185     15.1.1
# 186     15.1.2
# 187     15.2.1
# 188     15.3.1
# 189     15.4.1
# 190     15.4.2
# 191     15.5.1
# 192     15.6.1
# 193     15.7.1
# 194     15.8.1
# 195     15.9.1
# 196     15.b.1
# 197     15.c.1
# 198     15.a.1
# 199     16.1.1
# 200     16.1.2
# 201     16.1.3
# 202     16.1.4
# 203     16.2.1
# 204     16.2.2
# 205     16.2.3
# 206     16.3.1
# 207     16.3.2
# 208     16.3.3
# 209     16.4.1
# 210     16.4.2
# 211     16.5.1
# 212     16.5.2
# 213     16.6.1
# 214     16.6.2
# 215     16.7.1
# 216     16.7.2
# 217     16.8.1
# 218     16.9.1
# 219     16.a.1
# 220     16.b.1
# 221    16.10.1
# 222    16.10.2
# 223     17.1.1
# 224     17.1.2
# 225     17.2.1
# 226     17.3.1
# 227     17.3.2
# 228     17.4.1
# 229     17.5.1
# 230     17.6.1
# 231     17.7.1
# 232     17.8.1
# 233     17.9.1
# 234    17.10.1
# 235    17.11.1
# 236    17.12.1
# 237    17.13.1
# 238    17.14.1
# 239    17.15.1
# 240    17.16.1
# 241    17.17.1
# 242    17.18.2
# 243    17.18.3
# 244    17.19.1
# 245    17.19.2
# Name: Index, dtype: object

# %%
set(B) - set(A)
# Out:
# {'16.a.1 ',
#  '16.b.1 ',
#  '17.1.1 ',
#  '17.1.2 ',
#  '17.18.1',
#  '17.2.1 ',
#  '17.3.1 ',
#  '17.3.2 ',
#  '17.4.1 ',
#  '17.5.1 ',
#  '17.6.1 ',
#  '17.7.1 ',
#  '17.8.1 ',
#  '17.9.1 ',
#  '8.10.'}
